# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import plotly as pl
import seaborn as sns
import warnings
warnings.filterwarnings("ignore")
# %matplotlib inline

# %% [markdown]
# ## BLS Dataset

# %%
bls_df = pd.read_excel("monthly-listing-3.xlsx",header=1)
bls_df = bls_df[~bls_df['States'].isna()]
bls_df["NAICS_col"] = bls_df["Industry code[1]"].astype(str).str[:2]
bls_df["start_year"] = pd.DatetimeIndex(bls_df["Work stoppage beginning date"]).year
bls_df["end_year"] = pd.DatetimeIndex(bls_df["Work stoppage ending date"]).year
bls_df = bls_df[bls_df['start_year'] >= 1993]
bls_df.head()
# Out:
#                   Organizations involved          States            Areas  \
# 1                         Boeing Company              WA          Seattle
# 2                     Boston Gas Company              MA           Boston
# 3  Bituminous Coal Operators Association  IN, IL, KY, WV  Multiple states
# 4                       Douglas Aircraft              CA              NaN
# 5                    Allied Signal Corp.              VA         Hopewell
#
#           Ownership Industry code[1]  \
# 1  Private industry           336411
# 2  Private industry            22121
# 3  Private industry           212112
# 4  Private industry           336411
# 5  Private industry           325222
#
#                                                Union Union acronym  \
# 1  Seattle Professional Engineering Employees Ass...         SPEEA
# 2                                United Steelworkers           USW
# 3                     United Mine Workers of America          UMWA
# 4            International Association of Machinists           IAM
# 5             International Brotherhood of Teamsters           IBT
#
#   Union Local Bargaining unit Work stoppage beginning date  \
# 1         NaN             NaN                   1993-01-19
# 2       12003             NaN                   1993-01-24
# 3         NaN             NaN                   1993-02-02
# 4         NaN             NaN                   1993-03-02
# 5         NaN             NaN                   1993-03-22
#
#   Work stoppage ending date  Number of workers[2]  \
# 1                1993-01-19               21000.0
# 2                1993-05-20                1000.0
# 3                1993-03-02                6700.0
# 4                1993-03-03                6800.0
# 5                1993-04-21                1600.0
#
#    Days idle, cumulative for this work stoppage[3]  \
# 1                                          21000.0
# 2                                          83000.0
# 3                                         103400.0
# 4                                          13600.0
# 5                                          36800.0
#
#                                                 Note NAICS_col  start_year  \
# 1  The union name was changed to the Society of P...        33        1993
# 2  Boston Gas Company also does business as "Nati...        22        1993
# 3  Number of workers involved increased from 5,00...        21        1993
# 4                                                NaN        33        1993
# 5                                                NaN        32        1993
#
#    end_year
# 1      1993
# 2      1993
# 3      1993
# 4      1993
# 5      1993

# %%
testing_df = bls_df.copy()
for index, row in testing_df.iterrows():
    if "," in row['States']:
        states_list = row['States'].split(",")
        testing_df.loc[index, 'States'] = states_list[0]
        for i in np.arange(1,len(states_list)):
            row_2 = row
            row_2['States'] = states_list[i]
            testing_df.loc[testing_df.index.max()+1, :] = row_2
bls_df = testing_df
bls_df.head()
# Out:
#                   Organizations involved States            Areas  \
# 1                         Boeing Company     WA          Seattle
# 2                     Boston Gas Company     MA           Boston
# 3  Bituminous Coal Operators Association     IN  Multiple states
# 4                       Douglas Aircraft     CA              NaN
# 5                    Allied Signal Corp.     VA         Hopewell
#
#           Ownership Industry code[1]  \
# 1  Private industry           336411
# 2  Private industry            22121
# 3  Private industry           212112
# 4  Private industry           336411
# 5  Private industry           325222
#
#                                                Union Union acronym  \
# 1  Seattle Professional Engineering Employees Ass...         SPEEA
# 2                                United Steelworkers           USW
# 3                     United Mine Workers of America          UMWA
# 4            International Association of Machinists           IAM
# 5             International Brotherhood of Teamsters           IBT
#
#   Union Local Bargaining unit Work stoppage beginning date  \
# 1         NaN             NaN                   1993-01-19
# 2       12003             NaN                   1993-01-24
# 3         NaN             NaN                   1993-02-02
# 4         NaN             NaN                   1993-03-02
# 5         NaN             NaN                   1993-03-22
#
#   Work stoppage ending date  Number of workers[2]  \
# 1                1993-01-19               21000.0
# 2                1993-05-20                1000.0
# 3                1993-03-02                6700.0
# 4                1993-03-03                6800.0
# 5                1993-04-21                1600.0
#
#    Days idle, cumulative for this work stoppage[3]  \
# 1                                          21000.0
# 2                                          83000.0
# 3                                         103400.0
# 4                                          13600.0
# 5                                          36800.0
#
#                                                 Note NAICS_col  start_year  \
# 1  The union name was changed to the Society of P...        33      1993.0
# 2  Boston Gas Company also does business as "Nati...        22      1993.0
# 3  Number of workers involved increased from 5,00...        21      1993.0
# 4                                                NaN        33      1993.0
# 5                                                NaN        32      1993.0
#
#    end_year
# 1    1993.0
# 2    1993.0
# 3    1993.0
# 4    1993.0
# 5    1993.0

# %%
bls_df['States'] = bls_df['States'].str.strip()
bls_df = bls_df[bls_df['States'].str.len()<=2]
bls_df.head()
# Out:
#                   Organizations involved States            Areas  \
# 1                         Boeing Company     WA          Seattle
# 2                     Boston Gas Company     MA           Boston
# 3  Bituminous Coal Operators Association     IN  Multiple states
# 4                       Douglas Aircraft     CA              NaN
# 5                    Allied Signal Corp.     VA         Hopewell
#
#           Ownership Industry code[1]  \
# 1  Private industry           336411
# 2  Private industry            22121
# 3  Private industry           212112
# 4  Private industry           336411
# 5  Private industry           325222
#
#                                                Union Union acronym  \
# 1  Seattle Professional Engineering Employees Ass...         SPEEA
# 2                                United Steelworkers           USW
# 3                     United Mine Workers of America          UMWA
# 4            International Association of Machinists           IAM
# 5             International Brotherhood of Teamsters           IBT
#
#   Union Local Bargaining unit Work stoppage beginning date  \
# 1         NaN             NaN                   1993-01-19
# 2       12003             NaN                   1993-01-24
# 3         NaN             NaN                   1993-02-02
# 4         NaN             NaN                   1993-03-02
# 5         NaN             NaN                   1993-03-22
#
#   Work stoppage ending date  Number of workers[2]  \
# 1                1993-01-19               21000.0
# 2                1993-05-20                1000.0
# 3                1993-03-02                6700.0
# 4                1993-03-03                6800.0
# 5                1993-04-21                1600.0
#
#    Days idle, cumulative for this work stoppage[3]  \
# 1                                          21000.0
# 2                                          83000.0
# 3                                         103400.0
# 4                                          13600.0
# 5                                          36800.0
#
#                                                 Note NAICS_col  start_year  \
# 1  The union name was changed to the Society of P...        33      1993.0
# 2  Boston Gas Company also does business as "Nati...        22      1993.0
# 3  Number of workers involved increased from 5,00...        21      1993.0
# 4                                                NaN        33      1993.0
# 5                                                NaN        32      1993.0
#
#    end_year
# 1    1993.0
# 2    1993.0
# 3    1993.0
# 4    1993.0
# 5    1993.0

# %%
bls_df['num_years'] = bls_df["end_year"] - bls_df["start_year"] + 1
bls_df['num_years'].sum()
# Out:
# 915.0

# %%
testing_df = bls_df.copy()
for index, row in testing_df.iterrows():
    if row['num_years'] > 1:
        i = row['num_years']-1
        start_year = row['start_year']
        while i != 0:
            row_2 = row
            row_2['start_year'] = start_year + i
            testing_df.loc[testing_df.index.max()+1, :] = row_2
            i = i - 1
bls_df = testing_df
bls_df.head()
# Out:
#                   Organizations involved States            Areas  \
# 1                         Boeing Company     WA          Seattle
# 2                     Boston Gas Company     MA           Boston
# 3  Bituminous Coal Operators Association     IN  Multiple states
# 4                       Douglas Aircraft     CA              NaN
# 5                    Allied Signal Corp.     VA         Hopewell
#
#           Ownership Industry code[1]  \
# 1  Private industry           336411
# 2  Private industry            22121
# 3  Private industry           212112
# 4  Private industry           336411
# 5  Private industry           325222
#
#                                                Union Union acronym  \
# 1  Seattle Professional Engineering Employees Ass...         SPEEA
# 2                                United Steelworkers           USW
# 3                     United Mine Workers of America          UMWA
# 4            International Association of Machinists           IAM
# 5             International Brotherhood of Teamsters           IBT
#
#   Union Local Bargaining unit Work stoppage beginning date  \
# 1         NaN             NaN                   1993-01-19
# 2       12003             NaN                   1993-01-24
# 3         NaN             NaN                   1993-02-02
# 4         NaN             NaN                   1993-03-02
# 5         NaN             NaN                   1993-03-22
#
#   Work stoppage ending date  Number of workers[2]  \
# 1                1993-01-19               21000.0
# 2                1993-05-20                1000.0
# 3                1993-03-02                6700.0
# 4                1993-03-03                6800.0
# 5                1993-04-21                1600.0
#
#    Days idle, cumulative for this work stoppage[3]  \
# 1                                          21000.0
# 2                                          83000.0
# 3                                         103400.0
# 4                                          13600.0
# 5                                          36800.0
#
#                                                 Note NAICS_col  start_year  \
# 1  The union name was changed to the Society of P...        33      1993.0
# 2  Boston Gas Company also does business as "Nati...        22      1993.0
# 3  Number of workers involved increased from 5,00...        21      1993.0
# 4                                                NaN        33      1993.0
# 5                                                NaN        32      1993.0
#
#    end_year  num_years
# 1    1993.0        1.0
# 2    1993.0        1.0
# 3    1993.0        1.0
# 4    1993.0        1.0
# 5    1993.0        1.0

# %%
bls_df.to_csv('bls_testing.csv')

# %%
grouped_bls_df = bls_df.groupby(['States','start_year'])['Number of workers[2]'].sum().reset_index()
grouped_bls_df
# Out:
#     States  start_year  Number of workers[2]
# 0       AK      1994.0                2900.0
# 1       AK      1999.0                1000.0
# 2       AL      1993.0                1200.0
# 3       AL      1994.0                3200.0
# 4       AL      1996.0                1100.0
# ..     ...         ...                   ...
# 486     WV      2003.0                3200.0
# 487     WV      2015.0                2200.0
# 488     WV      2016.0                2200.0
# 489     WV      2018.0               36400.0
# 490     WV      2019.0               36400.0
#
# [491 rows x 3 columns]

# %% [markdown]
# ## FMCS Dataset

# %%
FMCS_df = pd.read_csv("work_stoppages.csv")
FMCS_df = FMCS_df[~FMCS_df['City, State'].isna()]
FMCS_df = FMCS_df[FMCS_df['# Idled'] >= 1000]
FMCS_df["start_year"] = pd.DatetimeIndex(FMCS_df["Start Date"]).year
FMCS_df["end_year"] = pd.DatetimeIndex(FMCS_df["End Date"]).year
FMCS_df = FMCS_df[~FMCS_df['City, State'].str.endswith(", ")]
FMCS_df['State'] = FMCS_df['City, State'].str[-2:]
FMCS_df = FMCS_df[FMCS_df['start_year'] >= 1993]
FMCS_df = FMCS_df[~(FMCS_df["Start Date"] == FMCS_df["End Date"])]
FMCS_df.head()
# Out:
#                                                Employer  \
# 6814                                    Caterpillar Inc
# 7365           Douglas Aircraft Company (two Locations)
# 7497                                 Boeing Company The
# 7522  Independent Bituminous Coal Bargaining Allianc...
# 7524                 Fieldcrest Cannon Inc (section 28)
#
#                                  Union Union Local   Case Number  BU  NAICS  \
# 6814                         UAW MULTI         NaN  1991JU003706 NaN    NaN
# 7365                           IAM 720         NaN  1992KR003410 NaN    NaN
# 7497                             SPEEA         NaN  1993BP000528 NaN    NaN
# 7522                               UMW         NaN  1993CN000462 NaN    NaN
# 7524  ACTWU BI COUNTY N NC & S GA DIST         NaN  1993CN000511 NaN    NaN
#
#                                         Industry     City, State  # Idled  \
# 6814                               Manufacturing      Peoria, IL  11500.0
# 7365                               Manufacturing    Torrance, CA   6759.0
# 7497                               Manufacturing     Seattle, WA   7000.0
# 7522  Mining, Quarrying and Oil & Gas Extraction  Birmingham, AL   1200.0
# 7524                               Manufacturing        Eden, NC   1500.0
#
#      Start Date End Date  Duration  start_year  end_year State
# 6814    6/21/94  12/4/95       NaN        1994    1995.0    IL
# 7365     3/2/93   3/3/93       NaN        1993    1993.0    CA
# 7497    1/21/93  1/22/93       NaN        1993    1993.0    WA
# 7522    7/14/93  7/16/93       NaN        1993    1993.0    AL
# 7524    5/17/93  5/19/93       NaN        1993    1993.0    NC

# %%
end_years_list = pd.DatetimeIndex(pd.DatetimeIndex(FMCS_df[(FMCS_df["end_year"].isna()) & ~(FMCS_df["Duration"].isna())]['Start Date']) + pd.to_timedelta(
    FMCS_df[(FMCS_df["end_year"].isna()) & ~(FMCS_df["Duration"].isna())]['Duration'], unit='D')).year
FMCS_df.loc[(FMCS_df["end_year"].isna()) & ~(FMCS_df["Duration"].isna()), "end_year"] = end_years_list
FMCS_df.loc[(FMCS_df["end_year"].isna()), "end_year"] = FMCS_df.loc[(FMCS_df["end_year"].isna()), "start_year"]
FMCS_df.loc[(FMCS_df["end_year"].isna()), :]
# Out:
# Empty DataFrame
# Columns: [Employer, Union, Union Local, Case Number, BU, NAICS, Industry, City, State, # Idled, Start Date, End Date, Duration, start_year, end_year, State]
# Index: []

# %%
FMCS_df['num_years'] = FMCS_df["end_year"] - FMCS_df["start_year"] + 1
FMCS_df.head()
# Out:
#                                                Employer  \
# 6814                                    Caterpillar Inc
# 7365           Douglas Aircraft Company (two Locations)
# 7497                                 Boeing Company The
# 7522  Independent Bituminous Coal Bargaining Allianc...
# 7524                 Fieldcrest Cannon Inc (section 28)
#
#                                  Union Union Local   Case Number  BU  NAICS  \
# 6814                         UAW MULTI         NaN  1991JU003706 NaN    NaN
# 7365                           IAM 720         NaN  1992KR003410 NaN    NaN
# 7497                             SPEEA         NaN  1993BP000528 NaN    NaN
# 7522                               UMW         NaN  1993CN000462 NaN    NaN
# 7524  ACTWU BI COUNTY N NC & S GA DIST         NaN  1993CN000511 NaN    NaN
#
#                                         Industry     City, State  # Idled  \
# 6814                               Manufacturing      Peoria, IL  11500.0
# 7365                               Manufacturing    Torrance, CA   6759.0
# 7497                               Manufacturing     Seattle, WA   7000.0
# 7522  Mining, Quarrying and Oil & Gas Extraction  Birmingham, AL   1200.0
# 7524                               Manufacturing        Eden, NC   1500.0
#
#      Start Date End Date  Duration  start_year  end_year State  num_years
# 6814    6/21/94  12/4/95       NaN        1994    1995.0    IL        2.0
# 7365     3/2/93   3/3/93       NaN        1993    1993.0    CA        1.0
# 7497    1/21/93  1/22/93       NaN        1993    1993.0    WA        1.0
# 7522    7/14/93  7/16/93       NaN        1993    1993.0    AL        1.0
# 7524    5/17/93  5/19/93       NaN        1993    1993.0    NC        1.0

# %%
testing_df = FMCS_df.copy()
for index, row in testing_df.iterrows():
    if row['num_years'] > 1:
        i = row['num_years']-1
        start_year = row['start_year']
        while i != 0:
            row_2 = row
            row_2['start_year'] = start_year + i
            testing_df.loc[testing_df.index.max()+1, :] = row_2
            i = i - 1
FMCS_df = testing_df
FMCS_df
# Out:
#                                                 Employer  \
# 6814                                     Caterpillar Inc
# 7365            Douglas Aircraft Company (two Locations)
# 7497                                  Boeing Company The
# 7522   Independent Bituminous Coal Bargaining Allianc...
# 7524                  Fieldcrest Cannon Inc (section 28)
# ...                                                  ...
# 14338                                   Charter/Spectrum
# 14339                                   Charter/Spectrum
# 14340                                   Charter/Spectrum
# 14341                                      National Grid
# 14342                             ASARCO Multiple Unions
#
#                                   Union Union Local   Case Number      BU  \
# 6814                          UAW MULTI         NaN  1991JU003706     NaN
# 7365                            IAM 720         NaN  1992KR003410     NaN
# 7497                              SPEEA         NaN  1993BP000528     NaN
# 7522                                UMW         NaN  1993CN000462     NaN
# 7524   ACTWU BI COUNTY N NC & S GA DIST         NaN  1993CN000511     NaN
# ...                                 ...         ...           ...     ...
# 14338                            IBEW 3           3   2.01709E+11  1800.0
# 14339                            IBEW 3           3   2.01709E+11  1800.0
# 14340                            IBEW 3           3   2.01709E+11  1800.0
# 14341                         USW 12003       12003  2018N1001656   875.0
# 14342         USW IBB IAM IUOE IBEW IBT         NaN    2.0209E+11  2108.0
#
#        NAICS                                    Industry     City, State  \
# 6814     NaN                               Manufacturing      Peoria, IL
# 7365     NaN                               Manufacturing    Torrance, CA
# 7497     NaN                               Manufacturing     Seattle, WA
# 7522     NaN  Mining, Quarrying and Oil & Gas Extraction  Birmingham, AL
# 7524     NaN                               Manufacturing        Eden, NC
# ...      ...                                         ...             ...
# 14338   54.0         Professional, Scientific &Tech Serv    New York, NJ
# 14339   54.0         Professional, Scientific &Tech Serv    New York, NJ
# 14340   54.0         Professional, Scientific &Tech Serv    New York, NJ
# 14341   22.0                                   Utilities     Waltham, MA
# 14342   21.0             Mining and Oil & Gas Extraction      Tucson, AZ
#
#        # Idled Start Date End Date  Duration  start_year  end_year State  \
# 6814   11500.0    6/21/94  12/4/95       NaN      1994.0    1995.0    IL
# 7365    6759.0     3/2/93   3/3/93       NaN      1993.0    1993.0    CA
# 7497    7000.0    1/21/93  1/22/93       NaN      1993.0    1993.0    WA
# 7522    1200.0    7/14/93  7/16/93       NaN      1993.0    1993.0    AL
# 7524    1500.0    5/17/93  5/19/93       NaN      1993.0    1993.0    NC
# ...        ...        ...      ...       ...         ...       ...   ...
# 14338   1800.0    3/29/17      NaN    1130.0      2020.0    2020.0    NJ
# 14339   1800.0    3/29/17      NaN    1130.0      2019.0    2020.0    NJ
# 14340   1800.0    3/29/17      NaN    1130.0      2018.0    2020.0    NJ
# 14341   1200.0    6/25/18   1/7/19     197.0      2019.0    2019.0    MA
# 14342   2108.0   10/14/19      NaN     262.0      2020.0    2020.0    AZ
#
#        num_years
# 6814         2.0
# 7365         1.0
# 7497         1.0
# 7522         1.0
# 7524         1.0
# ...          ...
# 14338        4.0
# 14339        4.0
# 14340        4.0
# 14341        2.0
# 14342        2.0
#
# [524 rows x 16 columns]

# %%
FMCS_df = FMCS_df[~FMCS_df.duplicated(['Employer','# Idled','start_year'])]
FMCS_df.head()
# Out:
#                                                Employer  \
# 6814                                    Caterpillar Inc
# 7365           Douglas Aircraft Company (two Locations)
# 7497                                 Boeing Company The
# 7522  Independent Bituminous Coal Bargaining Allianc...
# 7524                 Fieldcrest Cannon Inc (section 28)
#
#                                  Union Union Local   Case Number  BU  NAICS  \
# 6814                         UAW MULTI         NaN  1991JU003706 NaN    NaN
# 7365                           IAM 720         NaN  1992KR003410 NaN    NaN
# 7497                             SPEEA         NaN  1993BP000528 NaN    NaN
# 7522                               UMW         NaN  1993CN000462 NaN    NaN
# 7524  ACTWU BI COUNTY N NC & S GA DIST         NaN  1993CN000511 NaN    NaN
#
#                                         Industry     City, State  # Idled  \
# 6814                               Manufacturing      Peoria, IL  11500.0
# 7365                               Manufacturing    Torrance, CA   6759.0
# 7497                               Manufacturing     Seattle, WA   7000.0
# 7522  Mining, Quarrying and Oil & Gas Extraction  Birmingham, AL   1200.0
# 7524                               Manufacturing        Eden, NC   1500.0
#
#      Start Date End Date  Duration  start_year  end_year State  num_years
# 6814    6/21/94  12/4/95       NaN      1994.0    1995.0    IL        2.0
# 7365     3/2/93   3/3/93       NaN      1993.0    1993.0    CA        1.0
# 7497    1/21/93  1/22/93       NaN      1993.0    1993.0    WA        1.0
# 7522    7/14/93  7/16/93       NaN      1993.0    1993.0    AL        1.0
# 7524    5/17/93  5/19/93       NaN      1993.0    1993.0    NC        1.0

# %%
FMCS_df.to_csv('FMCS_testing.csv')

# %%
FMCS_df = pd.read_csv('FMCS_testing_2.csv')
FMCS_df = FMCS_df.iloc[:,1:]
FMCS_df
# Out:
#                                               Employer  \
# 0                                      Caterpillar Inc
# 1             Douglas Aircraft Company (two Locations)
# 2                                   Boeing Company The
# 3    Independent Bituminous Coal Bargaining Allianc...
# 4                   Fieldcrest Cannon Inc (section 28)
# ..                                                 ...
# 371                    FairPoint Communications - Yelm
# 372                                   Charter/Spectrum
# 373                                   Charter/Spectrum
# 374                                   Charter/Spectrum
# 375                                      National Grid
#
#                                 Union Union Local   Case Number      BU  \
# 0                           UAW MULTI         NaN  1991JU003706     NaN
# 1                             IAM 720         NaN  1992KR003410     NaN
# 2                               SPEEA         NaN  1993BP000528     NaN
# 3                                 UMW         NaN  1993CN000462     NaN
# 4    ACTWU BI COUNTY N NC & S GA DIST         NaN  1993CN000511     NaN
# ..                                ...         ...           ...     ...
# 371                  IBEW Local SCT-9         NaN  2014N0502678     NaN
# 372                            IBEW 3           3      2.02E+11  1800.0
# 373                            IBEW 3           3      2.02E+11  1800.0
# 374                            IBEW 3           3      2.02E+11  1800.0
# 375                         USW 12003       12003  2018N1001656   875.0
#
#      NAICS                                    Industry  \
# 0      NaN                               Manufacturing
# 1      NaN                               Manufacturing
# 2      NaN                               Manufacturing
# 3      NaN  Mining, Quarrying and Oil & Gas Extraction
# 4      NaN                               Manufacturing
# ..     ...                                         ...
# 371    NaN                                   Utilities
# 372   54.0         Professional, Scientific &Tech Serv
# 373   54.0         Professional, Scientific &Tech Serv
# 374   54.0         Professional, Scientific &Tech Serv
# 375   22.0                                   Utilities
#
#                   City, State  # Idled Start Date End Date  Duration  \
# 0                  Peoria, IL    14000    6/21/94  12/4/95       NaN
# 1                Torrance, CA     6800     3/2/93   3/3/93       NaN
# 2                 Seattle, WA    21000    1/21/93  1/22/93       NaN
# 3              Birmingham, AL     6700    7/14/93  7/16/93       NaN
# 4                    Eden, NC     2000    5/17/93  5/19/93       NaN
# ..                        ...      ...        ...      ...       ...
# 371  Various - ME, NH, VT, NH     1700   10/17/14  2/24/15       NaN
# 372              New York, NJ     1800    3/29/17      NaN    1130.0
# 373              New York, NJ     1800    3/29/17      NaN    1130.0
# 374              New York, NJ     1800    3/29/17      NaN    1130.0
# 375               Waltham, MA     1200    6/25/18   1/7/19     197.0
#
#      start_year  end_year State  num_years
# 0          1994      1995    IL          2
# 1          1993      1993    CA          1
# 2          1993      1993    WA          1
# 3          1993      1993    AL          1
# 4          1993      1993    NC          1
# ..          ...       ...   ...        ...
# 371        2015      2015    NH          2
# 372        2020      2020    NJ          4
# 373        2019      2020    NJ          4
# 374        2018      2020    NJ          4
# 375        2019      2019    MA          2
#
# [376 rows x 16 columns]

# %%
grouped_fmcs_df = FMCS_df.groupby(["State","start_year"])["# Idled"].sum().reset_index()
grouped_fmcs_df.head()
# Out:
#   State  start_year  # Idled
# 0    AK        1999     1000
# 1    AL        1993     6700
# 2    AL        1994     2000
# 3    AL        1996     1100
# 4    AL        1997     1000

# %% [markdown]
# ## Union Member Dataset

# %%
union_df = pd.read_csv("union_membership.csv")
union_df['State'].unique()
# Out:
# array(['Alabama', 'Alaska', 'Arizona', 'Arkansas', 'California',
#        'Colorado', 'Connecticut', 'Delaware', 'District of Columbia',
#        'Florida', 'Georgia', 'Hawaii', 'Idaho', 'Illinois', 'Indiana',
#        'Iowa', 'Kansas', 'Kentucky', 'Louisiana', 'Maine', 'Maryland',
#        'Massachusetts', 'Michigan', 'Minnesota', 'Mississippi',
#        'Missouri', 'Montana', 'Nebraska', 'Nevada', 'New Hampshire',
#        'New Jersey', 'New Mexico', 'New York', 'North Carolina',
#        'North Dakota', 'Ohio', 'Oklahoma', 'Oregon', 'Pennsylvania',
#        'Rhode Island', 'South Carolina', 'South Dakota', 'Tennessee',
#        'Texas', 'Utah', 'Vermont', 'Virginia', 'Washington',
#        'West Virginia', 'Wisconsin', 'Wyoming'], dtype=object)

# %%
us_state_to_abbrev_union = {"State" : {
    "Alabama": "AL",
    "Alaska": "AK",
    "Arizona": "AZ",
    "Arkansas": "AR",
    "California": "CA",
    "Colorado": "CO",
    "Connecticut": "CT",
    "Delaware": "DE",
    "Florida": "FL",
    "Georgia": "GA",
    "Hawaii": "HI",
    "Idaho": "ID",
    "Illinois": "IL",
    "Indiana": "IN",
    "Iowa": "IA",
    "Kansas": "KS",
    "Kentucky": "KY",
    "Louisiana": "LA",
    "Maine": "ME",
    "Maryland": "MD",
    "Massachusetts": "MA",
    "Michigan": "MI",
    "Minnesota": "MN",
    "Mississippi": "MS",
    "Missouri": "MO",
    "Montana": "MT",
    "Nebraska": "NE",
    "Nevada": "NV",
    "New Hampshire": "NH",
    "New Jersey": "NJ",
    "New Mexico": "NM",
    "New York": "NY",
    "North Carolina": "NC",
    "North Dakota": "ND",
    "Ohio": "OH",
    "Oklahoma": "OK",
    "Oregon": "OR",
    "Pennsylvania": "PA",
    "Rhode Island": "RI",
    "South Carolina": "SC",
    "South Dakota": "SD",
    "Tennessee": "TN",
    "Texas": "TX",
    "Utah": "UT",
    "Vermont": "VT",
    "Virginia": "VA",
    "Washington": "WA",
    "West Virginia": "WV",
    "Wisconsin": "WI",
    "Wyoming": "WY",
    "District of Columbia": "DC",
    "American Samoa": "AS",
    "Guam": "GU",
    "Northern Mariana Islands": "MP",
    "Puerto Rico": "PR",
    "United States Minor Outlying Islands": "UM",
    "U.S. Virgin Islands": "VI",
}}
union_df = union_df.replace(us_state_to_abbrev_union)
union_df_priv = union_df[union_df['Sector'] == 'Private'][["Year","State","% Mem",'Employment (in 1000s)']]
union_df_priv.head()
# Out:
#     Year State  % Mem Employment (in 1000s)
# 2   1993    AL  12.0%                 1,381
# 7   1993    AK  10.3%                   165
# 12  1993    AZ   5.2%                 1,212
# 17  1993    AR   7.5%                   778
# 22  1993    CA  11.6%                 9,967

# %% [markdown]
# ## Political Lean Dataset

# %%
poli_df = pd.read_csv("1976-2020-house.csv")
poli_df = poli_df[poli_df['year'] >= 1993]
poli_df = poli_df[~poli_df['state_po'].isin(['DC'])]
poli_df.head()
# Out:
#        year    state state_po  state_fips  state_cen  state_ic    office  \
# 11083  1994  ALABAMA       AL           1         63        41  US HOUSE
# 11084  1994  ALABAMA       AL           1         63        41  US HOUSE
# 11085  1994  ALABAMA       AL           1         63        41  US HOUSE
# 11086  1994  ALABAMA       AL           1         63        41  US HOUSE
# 11087  1994  ALABAMA       AL           1         63        41  US HOUSE
#
#        district stage runoff  special       candidate       party  writein  \
# 11083         1   GEN  False    False      DON WOMACK    DEMOCRAT    False
# 11084         1   GEN  False    False  SONNY CALLAHAN  REPUBLICAN    False
# 11085         1   GEN  False    False         WRITEIN         NaN     True
# 11086         2   GEN  False    False   BRIAN DOWLING    DEMOCRAT    False
# 11087         2   GEN  False    False   TERRY EVERETT  REPUBLICAN    False
#
#         mode  candidatevotes  totalvotes  unofficial   version  fusion_ticket
# 11083  TOTAL           50227      153767       False  20220331          False
# 11084  TOTAL          103431      153767       False  20220331          False
# 11085  TOTAL             109      153767       False  20220331          False
# 11086  TOTAL           44694      169213       False  20220331          False
# 11087  TOTAL          124465      169213       False  20220331          False

# %%
votes_by_party = poli_df.groupby(['state_po','year','party'])['candidatevotes'].sum().reset_index()
votes_by_party = votes_by_party[votes_by_party['party'] == 'REPUBLICAN']
votes_by_party = votes_by_party.set_index(['state_po','year']).drop(columns=['party'])
total_votes = poli_df.groupby(['state_po','year','district'])['totalvotes'].first().reset_index()
total_votes = total_votes.groupby(['state_po','year'])['totalvotes'].sum().reset_index()
total_votes = total_votes.set_index(['state_po','year'])
votes_by_party.head(), total_votes.head()
# Out:
# (               candidatevotes
#  state_po year
#  AK       1994          118537
#           1996          138834
#           1998          139676
#           2000          190862
#           2002          169685,
#                 totalvotes
#  state_po year
#  AK       1994      208240
#           1996      233700
#           1998      223300
#           2000      274393
#           2002      227725)

# %%
poli_df.loc[(poli_df['state_po'] == 'MN') & (poli_df['year'].isin([1992])) & (poli_df['party'].isin(["INDEPENDENT-REPUBLICAN"])),'party'] = "REPUBLICAN"
poli_df.loc[(poli_df['state_po'] == 'HI') & (poli_df['year'].isin([1982])),:]['party'].unique()
poli_df.loc[(poli_df['state_po'] == 'DC') & (poli_df['year'].isin([2020])),:]['party'].unique()
poli_df.loc[(poli_df['state_po'] == 'VT') & (poli_df['year'].isin([2008,2016])),:]['party'].unique()
# Out:
# array(['INDEPENDENT', 'LIBERTY UNION', 'ENERGY INDEPENDENCE', 'DEMOCRAT',
#        'PROGRESSIVE', nan], dtype=object)

# %%
merged_poli_df = total_votes.merge(votes_by_party, left_index=True, right_index=True, how="left")
merged_poli_df['candidatevotes'] = merged_poli_df['candidatevotes'].fillna(0)
merged_poli_df['prop_rep_votes'] = merged_poli_df['candidatevotes']/merged_poli_df['totalvotes']
merged_poli_df
# Out:
#                totalvotes  candidatevotes  prop_rep_votes
# state_po year
# AK       1994      208240        118537.0        0.569233
#          1996      233700        138834.0        0.594069
#          1998      223300        139676.0        0.625508
#          2000      274393        190862.0        0.695579
#          2002      227725        169685.0        0.745131
# ...                   ...             ...             ...
# WY       2012      250700        166452.0        0.663949
#          2014      171153        113038.0        0.660450
#          2016      258788        156176.0        0.603490
#          2018      201245        127963.0        0.635857
#          2020      278503        185732.0        0.666894
#
# [700 rows x 3 columns]

# %%
full_poli_df = merged_poli_df.reset_index()
for state in full_poli_df['state_po'].unique():
    for year in np.arange(1995,2020,2):
        try:
            full_poli_df.loc[full_poli_df.index.max()+1,:] = full_poli_df.loc[
                (full_poli_df['state_po'] == state) & (full_poli_df['year'] == year-1),:].iloc[0]
            full_poli_df.loc[full_poli_df.index.max(),'year']=year
        except:
            print(state,year)
full_poli_df.head()
# Out:
#   state_po    year  totalvotes  candidatevotes  prop_rep_votes
# 0       AK  1994.0    208240.0        118537.0        0.569233
# 1       AK  1996.0    233700.0        138834.0        0.594069
# 2       AK  1998.0    223300.0        139676.0        0.625508
# 3       AK  2000.0    274393.0        190862.0        0.695579
# 4       AK  2002.0    227725.0        169685.0        0.745131

# %% [markdown]
# ## Minimum Wage Dataset

# %%
min_wage_df = pd.read_csv("min_wage.csv",encoding='cp1252')
min_wage_df = min_wage_df[min_wage_df['Year'] >= 1993]
min_wage_df
# Out:
#       Year          State  State.Minimum.Wage  \
# 1350  1993        Alabama                0.00
# 1351  1993         Alaska                4.75
# 1352  1993        Arizona                0.00
# 1353  1993       Arkansas                3.65
# 1354  1993     California                4.25
# ...    ...            ...                 ...
# 2857  2020       Virginia                7.25
# 2858  2020     Washington               13.50
# 2859  2020  West Virginia                8.75
# 2860  2020      Wisconsin                7.25
# 2861  2020        Wyoming                5.15
#
#       State.Minimum.Wage.2020.Dollars  Federal.Minimum.Wage  \
# 1350                             0.00                  4.25
# 1351                             8.50                  4.25
# 1352                             0.00                  4.25
# 1353                             6.53                  4.25
# 1354                             7.61                  4.25
# ...                               ...                   ...
# 2857                             7.25                  7.25
# 2858                            13.50                  7.25
# 2859                             8.75                  7.25
# 2860                             7.25                  7.25
# 2861                             5.15                  7.25
#
#       Federal.Minimum.Wage.2020.Dollars  Effective.Minimum.Wage  \
# 1350                               7.61                    4.25
# 1351                               7.61                    4.75
# 1352                               7.61                    4.25
# 1353                               7.61                    4.25
# 1354                               7.61                    4.25
# ...                                 ...                     ...
# 2857                               7.25                    7.25
# 2858                               7.25                   13.50
# 2859                               7.25                    8.75
# 2860                               7.25                    7.25
# 2861                               7.25                    7.25
#
#       Effective.Minimum.Wage.2020.Dollars  CPI.Average  \
# 1350                                 7.61       144.50
# 1351                                 8.50       144.50
# 1352                                 7.61       144.50
# 1353                                 7.61       144.50
# 1354                                 7.61       144.50
# ...                                   ...          ...
# 2857                                 7.25       258.66
# 2858                                13.50       258.66
# 2859                                 8.75       258.66
# 2860                                 7.25       258.66
# 2861                                 7.25       258.66
#
#      Department.Of.Labor.Uncleaned.Data  \
# 1350                                ...
# 1351                               4.75
# 1352                                ...
# 1353                               3.65
# 1354                               4.25
# ...                                 ...
# 2857                            7.25[c]
# 2858                               13.5
# 2859                               8.75
# 2860                               7.25
# 2861                               5.15
#
#       Department.Of.Labor.Cleaned.Low.Value  \
# 1350                                   0.00
# 1351                                   4.75
# 1352                                   0.00
# 1353                                   3.65
# 1354                                   4.25
# ...                                     ...
# 2857                                   7.25
# 2858                                  13.50
# 2859                                   8.75
# 2860                                   7.25
# 2861                                   5.15
#
#       Department.Of.Labor.Cleaned.Low.Value.2020.Dollars  \
# 1350                                               0.00
# 1351                                               8.50
# 1352                                               0.00
# 1353                                               6.53
# 1354                                               7.61
# ...                                                 ...
# 2857                                               7.25
# 2858                                              13.50
# 2859                                               8.75
# 2860                                               7.25
# 2861                                               5.15
#
#       Department.Of.Labor.Cleaned.High.Value  \
# 1350                                    0.00
# 1351                                    4.75
# 1352                                    0.00
# 1353                                    3.65
# 1354                                    4.25
# ...                                      ...
# 2857                                    7.25
# 2858                                   13.50
# 2859                                    8.75
# 2860                                    7.25
# 2861                                    5.15
#
#       Department.Of.Labor.Cleaned.High.Value.2020.Dollars Footnote
# 1350                                               0.00        NaN
# 1351                                               8.50        NaN
# 1352                                               0.00        NaN
# 1353                                               6.53        NaN
# 1354                                               7.61        NaN
# ...                                                 ...        ...
# 2857                                               7.25        [c]
# 2858                                              13.50        NaN
# 2859                                               8.75        NaN
# 2860                                               7.25        NaN
# 2861                                               5.15        NaN
#
# [1512 rows x 15 columns]

# %%
us_state_to_abbrev_min_wage = {"State" : {
    "Alabama": "AL",
    "Alaska": "AK",
    "Arizona": "AZ",
    "Arkansas": "AR",
    "California": "CA",
    "Colorado": "CO",
    "Connecticut": "CT",
    "Delaware": "DE",
    "Florida": "FL",
    "Georgia": "GA",
    "Hawaii": "HI",
    "Idaho": "ID",
    "Illinois": "IL",
    "Indiana": "IN",
    "Iowa": "IA",
    "Kansas": "KS",
    "Kentucky": "KY",
    "Louisiana": "LA",
    "Maine": "ME",
    "Maryland": "MD",
    "Massachusetts": "MA",
    "Michigan": "MI",
    "Minnesota": "MN",
    "Mississippi": "MS",
    "Missouri": "MO",
    "Montana": "MT",
    "Nebraska": "NE",
    "Nevada": "NV",
    "New Hampshire": "NH",
    "New Jersey": "NJ",
    "New Mexico": "NM",
    "New York": "NY",
    "North Carolina": "NC",
    "North Dakota": "ND",
    "Ohio": "OH",
    "Oklahoma": "OK",
    "Oregon": "OR",
    "Pennsylvania": "PA",
    "Rhode Island": "RI",
    "South Carolina": "SC",
    "South Dakota": "SD",
    "Tennessee": "TN",
    "Texas": "TX",
    "Utah": "UT",
    "Vermont": "VT",
    "Virginia": "VA",
    "Washington": "WA",
    "West Virginia": "WV",
    "Wisconsin": "WI",
    "Wyoming": "WY",
    "District of Columbia": "DC",
    "American Samoa": "AS",
    "Guam": "GU",
    "Northern Mariana Islands": "MP",
    "Puerto Rico": "PR",
    "United States Minor Outlying Islands": "UM",
    "U.S. Virgin Islands": "VI",
}}
min_wage_df = min_wage_df.replace(us_state_to_abbrev_min_wage)
min_wage_df.sort_values(['State','Year'],inplace=True)
min_wage_df = min_wage_df.reset_index().drop(columns=['index'])
min_wage_df.head()
# Out:
#    Year State  State.Minimum.Wage  State.Minimum.Wage.2020.Dollars  \
# 0  1993    AK                4.75                             8.50
# 1  1994    AK                4.75                             8.29
# 2  1995    AK                4.75                             8.06
# 3  1996    AK                4.75                             7.83
# 4  1997    AK                5.25                             8.46
#
#    Federal.Minimum.Wage  Federal.Minimum.Wage.2020.Dollars  \
# 0                  4.25                               7.61
# 1                  4.25                               7.42
# 2                  4.25                               7.21
# 3                  4.25                               7.01
# 4                  4.75                               7.66
#
#    Effective.Minimum.Wage  Effective.Minimum.Wage.2020.Dollars  CPI.Average  \
# 0                    4.75                                 8.50        144.5
# 1                    4.75                                 8.29        148.2
# 2                    4.75                                 8.06        152.4
# 3                    4.75                                 7.83        156.9
# 4                    5.25                                 8.46        160.5
#
#   Department.Of.Labor.Uncleaned.Data  Department.Of.Labor.Cleaned.Low.Value  \
# 0                               4.75                                   4.75
# 1                               4.75                                   4.75
# 2                               4.75                                   4.75
# 3                               4.75                                   4.75
# 4                               5.25                                   5.25
#
#    Department.Of.Labor.Cleaned.Low.Value.2020.Dollars  \
# 0                                               8.50
# 1                                               8.29
# 2                                               8.06
# 3                                               7.83
# 4                                               8.46
#
#    Department.Of.Labor.Cleaned.High.Value  \
# 0                                    4.75
# 1                                    4.75
# 2                                    4.75
# 3                                    4.75
# 4                                    5.25
#
#    Department.Of.Labor.Cleaned.High.Value.2020.Dollars Footnote
# 0                                               8.50        NaN
# 1                                               8.29        NaN
# 2                                               8.06        NaN
# 3                                               7.83        NaN
# 4                                               8.46        NaN

# %% [markdown]
# ## Nearest States Dataset

# %%
distances_df = pd.read_csv("distances_df.csv")
distances_df.head()
# Out:
#   state  latitude  longitude Closest State #1  Distance to Closest State #1  \
# 0    AL   32.7794   -86.8287               MS                    165.334460
# 1    AK   64.0685  -152.2782               WA                   1663.916968
# 2    AZ   34.2744  -111.6602               NM                    317.276353
# 3    AR   34.8938   -92.4426               MS                    218.135844
# 4    CA   37.1841  -119.4696               NV                    213.785465
#
#   Closest State #2  Distance to Closest State #2 Closest State #3  \
# 0               GA                    197.487904               TN
# 1               OR                   1861.858430               MT
# 2               UT                    346.924962               NV
# 3               MO                    238.775500               LA
# 4               UT                    448.579321               OR
#
#    Distance to Closest State #3 Closest State #4  \
# 0                    213.954618               LA
# 1                   1985.735915               ID
# 2                    444.202213               CO
# 3                    264.851958               OK
# 4                    469.217131               AZ
#
#    Distance to Closest State #4 Closest State #5  Distance to Closest State #5
# 0                    325.712907               KY                    339.003175
# 1                   1995.169309               ND                   2237.421669
# 2                    470.340950               CA                    482.459726
# 3                    289.663758               TN                    350.279840
# 4                    482.459726               ID                    556.046610

# %% [markdown]
# ## State Inflation Dataset

# %%
state_inflation_df = pd.read_csv("statecpi_beta.csv")
for i in ['pi_nt','pi_t','pi']:
    state_inflation_df[i + "_prop"] = state_inflation_df[i]/100+1
state_inflation_df = (state_inflation_df.groupby(['state','year'])[['pi_nt_prop','pi_t_prop','pi_prop']].agg(np.prod)-1)*100
state_inflation_df.rename(columns={'pi_nt_prop': 'pi_nt','pi_t_prop': 'pi_t','pi_prop': 'pi'},inplace=True)
state_inflation_df.reset_index(inplace=True)
state_inflation_df.head()
# Out:
#      state  year      pi_nt       pi_t         pi
# 0  Alabama  1989  15.782732  18.149607  17.063328
# 1  Alabama  1990  13.691798  16.391293  15.103246
# 2  Alabama  1991  24.342764   5.256562  15.858694
# 3  Alabama  1992   9.125672  -0.824136   5.000021
# 4  Alabama  1993  13.388873   5.596229  10.185112

# %%
us_state_inf_to_abbrev = {"state" : {
    "Alabama": "AL",
    "Alaska": "AK",
    "Arizona": "AZ",
    "Arkansas": "AR",
    "California": "CA",
    "Colorado": "CO",
    "Connecticut": "CT",
    "Delaware": "DE",
    "Florida": "FL",
    "Georgia": "GA",
    "Hawaii": "HI",
    "Idaho": "ID",
    "Illinois": "IL",
    "Indiana": "IN",
    "Iowa": "IA",
    "Kansas": "KS",
    "Kentucky": "KY",
    "Louisiana": "LA",
    "Maine": "ME",
    "Maryland": "MD",
    "Massachusetts": "MA",
    "Michigan": "MI",
    "Minnesota": "MN",
    "Mississippi": "MS",
    "Missouri": "MO",
    "Montana": "MT",
    "Nebraska": "NE",
    "Nevada": "NV",
    "New Hampshire": "NH",
    "New Jersey": "NJ",
    "New Mexico": "NM",
    "New York": "NY",
    "North Carolina": "NC",
    "North Dakota": "ND",
    "Ohio": "OH",
    "Oklahoma": "OK",
    "Oregon": "OR",
    "Pennsylvania": "PA",
    "Rhode Island": "RI",
    "South Carolina": "SC",
    "South Dakota": "SD",
    "Tennessee": "TN",
    "Texas": "TX",
    "Utah": "UT",
    "Vermont": "VT",
    "Virginia": "VA",
    "Washington": "WA",
    "West Virginia": "WV",
    "Wisconsin": "WI",
    "Wyoming": "WY",
    "District of Columbia": "DC",
    "American Samoa": "AS",
    "Guam": "GU",
    "Northern Mariana Islands": "MP",
    "Puerto Rico": "PR",
    "United States Minor Outlying Islands": "UM",
    "U.S. Virgin Islands": "VI",
}}
state_inflation_df = state_inflation_df.replace(us_state_inf_to_abbrev)
state_inflation_df
# Out:
#      state  year      pi_nt       pi_t         pi
# 0       AL  1989  15.782732  18.149607  17.063328
# 1       AL  1990  13.691798  16.391293  15.103246
# 2       AL  1991  24.342764   5.256562  15.858694
# 3       AL  1992   9.125672  -0.824136   5.000021
# 4       AL  1993  13.388873   5.596229  10.185112
# ...    ...   ...        ...        ...        ...
# 1170    WI  2013  10.199952  -1.088311   6.491816
# 1171    WI  2014   8.692873   2.716131   6.835408
# 1172    WI  2015   5.133358  -9.183445  -0.237336
# 1173    WI  2016   2.546422  -5.558837  -0.465041
# 1174    WI  2017   9.789466   4.999244   8.737010
#
# [1175 rows x 5 columns]

# %% [markdown]
# ## US Inflation Dataset

# %%
us_inf = pd.read_excel("us_inf.xlsx")
us_inf.head()
# Out:
#    Year  Jan  Feb  Mar  Apr  May  Jun  Jul  Aug  Sep  Oct  Nov  Dec  Annual  \
# 0  1993  3.5  3.6  3.4  3.5  3.4  3.3  3.2  3.3  3.2  3.0  3.1  3.2     3.3
# 1  1994  2.9  2.8  2.9  2.8  2.8  2.9  2.9  2.9  3.0  2.9  2.8  2.6     2.8
# 2  1995  2.9  3.0  3.0  3.1  3.1  3.0  3.0  2.9  2.9  3.0  3.0  3.0     3.0
# 3  1996  3.0  2.9  2.8  2.7  2.7  2.7  2.7  2.6  2.7  2.6  2.6  2.6     2.7
# 4  1997  2.5  2.5  2.5  2.7  2.5  2.4  2.4  2.3  2.2  2.3  2.2  2.2     2.4
#
#    HALF1  HALF2
# 0    3.4    3.2
# 1    2.8    2.9
# 2    3.0    3.0
# 3    2.7    2.7
# 4    2.6    2.2

# %% [markdown]
# ## Combining BLS and FMCS Datasets

# %%
lst = []
for x in grouped_bls_df['States'].unique():
    lst = lst + [x]
for x in grouped_fmcs_df['State'].unique():
    if x not in lst:
        lst = lst + [x]
for x in union_df_priv['State'].unique():
    if x not in lst:
        lst = lst + [x]
for x in full_poli_df['state_po'].unique():
    if x not in lst:
        lst = lst + [x]
print(lst)
# Out:
# ['AK', 'AL', 'AR', 'AZ', 'CA', 'CO', 'CT', 'DC', 'DE', 'FL', 'GA', 'HI', 'IA', 'ID', 'IL', 'IN', 'KS', 'KY', 'LA', 'MA', 'MD', 'ME', 'MI', 'MN', 'MO', 'MS', 'MT', 'NC', 'ND', 'NE', 'NH', 'NJ', 'NM', 'NV', 'NY', 'OH', 'OK', 'OR', 'PA', 'RI', 'SC', 'TN', 'TX', 'UT', 'VA', 'VT', 'WA', 'WI', 'WV', 'VI', 'SD', 'WY']

# %%
new_df = pd.DataFrame(columns=['State','Year','Strikers','FMCS Interest'])
new_df.loc[0,:] = ['AL',1990,1500,1950]
for state in lst:
    for year in np.arange(1993,2021):
        striking_workers = 0
        fmcs_workers = 0
        if len(grouped_bls_df[(grouped_bls_df['States'] == state) & (grouped_bls_df['start_year'] == year)]) == 1:
            striking_workers = grouped_bls_df[(grouped_bls_df['States'] == state) & (grouped_bls_df['start_year'] == year)]['Number of workers[2]'].iloc[0]
        elif len(grouped_bls_df[(grouped_bls_df['States'] == state) & (grouped_bls_df['start_year'] == year)]) > 1:
            print(state,year)
        if len(grouped_fmcs_df[(grouped_fmcs_df['State'] == state) & (grouped_fmcs_df['start_year'] == year)]) == 1:
            fmcs_workers = grouped_fmcs_df[(grouped_fmcs_df['State'] == state) & (grouped_fmcs_df['start_year'] == year)]['# Idled'].iloc[0]
        elif len(grouped_fmcs_df[(grouped_fmcs_df['State'] == state) & (grouped_fmcs_df['start_year'] == year)]) > 1:
            print(state,year)
        new_df.loc[new_df.index.max()+1,:] = [state,year,striking_workers,fmcs_workers]
new_df = new_df.iloc[1:,:]
new_df['valid strikers'] = new_df['Strikers'] - new_df['FMCS Interest']
new_df.head()
# Out:
#   State  Year Strikers FMCS Interest valid strikers
# 1    AK  1993        0             0              0
# 2    AK  1994   2900.0             0         2900.0
# 3    AK  1995        0             0              0
# 4    AK  1996        0             0              0
# 5    AK  1997        0             0              0

# %%
union_list = []
emplyed_workers_list = []
for state in lst:
    for year in np.arange(1993,2021):
        sub_df = union_df_priv.loc[(union_df_priv['State'] == state) & (union_df_priv['Year'] == year)]
        if len(sub_df) > 1:
            print(state, year)
        if len(sub_df) == 1:
            num = float((union_df_priv.loc[(union_df_priv['State'] == state) & (union_df_priv['Year'] == year)]['% Mem'].iloc[0])[:-1])
            num_2 = 1000*float((union_df_priv.loc[(union_df_priv['State'] == state) & (union_df_priv['Year'] == year)]['Employment (in 1000s)'].iloc[0]).replace(",",""))
        if len(sub_df) == 0:
            num = np.nan
            num_2 = np.nan
        union_list = union_list + [num]
        emplyed_workers_list = emplyed_workers_list + [num_2]
new_df['Priv Union Members (%)'] = union_list
new_df['Employed Workers'] = emplyed_workers_list
new_df['Employed Workers not on strike'] = new_df['Employed Workers'] - new_df['valid strikers']
new_df['prop not on strike'] = new_df['Employed Workers not on strike']/new_df['Employed Workers']
new_df.head()
# Out:
#   State  Year Strikers FMCS Interest valid strikers  Priv Union Members (%)  \
# 1    AK  1993        0             0              0                    10.3
# 2    AK  1994   2900.0             0         2900.0                    10.0
# 3    AK  1995        0             0              0                    11.4
# 4    AK  1996        0             0              0                    12.4
# 5    AK  1997        0             0              0                     9.6
#
#    Employed Workers Employed Workers not on strike prop not on strike
# 1          165000.0                       165000.0                1.0
# 2          163000.0                       160100.0           0.982209
# 3          151000.0                       151000.0                1.0
# 4          165000.0                       165000.0                1.0
# 5          169000.0                       169000.0                1.0

# %%
poli_list = []
for state in lst:
    for year in np.arange(1993,2021):
        sub_df = full_poli_df.loc[(full_poli_df['state_po'] == state) & (full_poli_df['year'] == year)]
        if len(sub_df) > 1:
            print(state, year)
        try:
            if len(sub_df) == 1:
                num = float((sub_df['prop_rep_votes'].iloc[0]))
            if len(sub_df) == 0:
                num = np.nan
        except:
            print(state, year)
        poli_list = poli_list + [num]
new_df['prop_rep'] = poli_list
new_df.head()
# Out:
#   State  Year Strikers FMCS Interest valid strikers  Priv Union Members (%)  \
# 1    AK  1993        0             0              0                    10.3
# 2    AK  1994   2900.0             0         2900.0                    10.0
# 3    AK  1995        0             0              0                    11.4
# 4    AK  1996        0             0              0                    12.4
# 5    AK  1997        0             0              0                     9.6
#
#    Employed Workers Employed Workers not on strike prop not on strike  \
# 1          165000.0                       165000.0                1.0
# 2          163000.0                       160100.0           0.982209
# 3          151000.0                       151000.0                1.0
# 4          165000.0                       165000.0                1.0
# 5          169000.0                       169000.0                1.0
#
#    prop_rep
# 1       NaN
# 2  0.569233
# 3  0.569233
# 4  0.594069
# 5  0.594069

# %%
min_wage_list = []
for state in lst:
    for year in np.arange(1993,2021):
        sub_df = min_wage_df.loc[(min_wage_df['State'] == state) & (min_wage_df['Year'] == year)]
        if len(sub_df) > 1:
            print(state, year)
        try:
            if len(sub_df) == 1:
                num = float((sub_df['State.Minimum.Wage'].iloc[0]))
            if len(sub_df) == 0:
                num = np.nan
        except:
            print(state, year)
        min_wage_list = min_wage_list + [num]
new_df['Min Wage'] = min_wage_list
new_df.head()
# Out:
#   State  Year Strikers FMCS Interest valid strikers  Priv Union Members (%)  \
# 1    AK  1993        0             0              0                    10.3
# 2    AK  1994   2900.0             0         2900.0                    10.0
# 3    AK  1995        0             0              0                    11.4
# 4    AK  1996        0             0              0                    12.4
# 5    AK  1997        0             0              0                     9.6
#
#    Employed Workers Employed Workers not on strike prop not on strike  \
# 1          165000.0                       165000.0                1.0
# 2          163000.0                       160100.0           0.982209
# 3          151000.0                       151000.0                1.0
# 4          165000.0                       165000.0                1.0
# 5          169000.0                       169000.0                1.0
#
#    prop_rep  Min Wage
# 1       NaN      4.75
# 2  0.569233      4.75
# 3  0.569233      4.75
# 4  0.594069      4.75
# 5  0.594069      5.25

# %%
us_inf_list = []
for state in lst:
    for year in np.arange(1993,2021):
        us_inf_list = us_inf_list+ [us_inf.loc[(us_inf['Year']==year), 'Annual'].iloc[0]]
new_df['us_inf'] =   us_inf_list
new_df.head()
# Out:
#   State  Year Strikers FMCS Interest valid strikers  Priv Union Members (%)  \
# 1    AK  1993        0             0              0                    10.3
# 2    AK  1994   2900.0             0         2900.0                    10.0
# 3    AK  1995        0             0              0                    11.4
# 4    AK  1996        0             0              0                    12.4
# 5    AK  1997        0             0              0                     9.6
#
#    Employed Workers Employed Workers not on strike prop not on strike  \
# 1          165000.0                       165000.0                1.0
# 2          163000.0                       160100.0           0.982209
# 3          151000.0                       151000.0                1.0
# 4          165000.0                       165000.0                1.0
# 5          169000.0                       169000.0                1.0
#
#    prop_rep  Min Wage  us_inf
# 1       NaN      4.75     3.3
# 2  0.569233      4.75     2.8
# 3  0.569233      4.75     3.0
# 4  0.594069      4.75     2.7
# 5  0.594069      5.25     2.4

# %%
state_inf_list = []
state_inf_t_list = []
state_inf_nt_list = []
for state in lst:
    for year in np.arange(1993,2021):
        sub_df = state_inflation_df.loc[(state_inflation_df['state'] == state) & (state_inflation_df['year'] == year)]
        if len(sub_df) > 1:
            print(state, year)
        try:
            if len(sub_df) == 1:
                num = float((sub_df['pi'].iloc[0]))
                num_2 = float((sub_df['pi_t'].iloc[0]))
                num_3 = float((sub_df['pi_nt'].iloc[0]))
            if len(sub_df) == 0:
                num, num_2, num_3 = np.nan, np.nan, np.nan
        except:
            print(state, year)
        state_inf_list = state_inf_list + [num]
        state_inf_t_list = state_inf_t_list + [num_2]
        state_inf_nt_list = state_inf_nt_list + [num_3]
        
new_df['state_inf'] = state_inf_list
new_df['state_inf_t'] = state_inf_t_list
new_df['state_inf_nt'] = state_inf_nt_list

new_df.head()
# Out:
#   State  Year Strikers FMCS Interest valid strikers  Priv Union Members (%)  \
# 1    AK  1993        0             0              0                    10.3
# 2    AK  1994   2900.0             0         2900.0                    10.0
# 3    AK  1995        0             0              0                    11.4
# 4    AK  1996        0             0              0                    12.4
# 5    AK  1997        0             0              0                     9.6
#
#    Employed Workers Employed Workers not on strike prop not on strike  \
# 1          165000.0                       165000.0                1.0
# 2          163000.0                       160100.0           0.982209
# 3          151000.0                       151000.0                1.0
# 4          165000.0                       165000.0                1.0
# 5          169000.0                       169000.0                1.0
#
#    prop_rep  Min Wage  us_inf  state_inf  state_inf_t  state_inf_nt
# 1       NaN      4.75     3.3   9.708451     0.526923     16.330164
# 2  0.569233      4.75     2.8   6.019952     0.004207     10.459492
# 3  0.569233      4.75     3.0   7.812813     6.326159      9.473906
# 4  0.594069      4.75     2.7  12.149973     8.822973     14.476239
# 5  0.594069      5.25     2.4   8.288585     2.779384     11.776124

# %%
new_df[new_df['state_inf'].isna()].groupby('State').size().index
#so many missing states
# Out:
# Index(['AK', 'AL', 'AR', 'AZ', 'CA', 'CO', 'CT', 'DC', 'DE', 'FL', 'GA', 'HI',
#        'IA', 'ID', 'IL', 'IN', 'KS', 'KY', 'LA', 'MA', 'MD', 'ME', 'MI', 'MN',
#        'MO', 'MS', 'MT', 'NC', 'ND', 'NE', 'NH', 'NJ', 'NM', 'NV', 'NY', 'OH',
#        'OK', 'OR', 'PA', 'RI', 'SC', 'SD', 'TN', 'TX', 'UT', 'VA', 'VI', 'VT',
#        'WA', 'WI', 'WV', 'WY'],
#       dtype='object', name='State')

# %%
strikers_list = []
fmcs_list = []
union_mem_list = []
minwages_list = []
propworkers_list = []
prop_strike_delta_list = []
for state in lst:
    sub_df = new_df[new_df['State'] == state][['Priv Union Members (%)','prop not on strike']].pct_change()
    strikers_list = strikers_list + new_df[new_df['State'] == state]['valid strikers'].replace(0,1).pct_change().tolist()
    union_mem_list = union_mem_list + sub_df['Priv Union Members (%)'].tolist()
    minwages_list = minwages_list + new_df[new_df['State'] == state]['Min Wage'].diff().tolist()
    propworkers_list = propworkers_list + sub_df['prop not on strike'].tolist()
    
new_df['strikers_diff'] = strikers_list
new_df['union_mem_diff'] = union_mem_list
new_df['change_prop_not_on_strike'] = propworkers_list
new_df['change_prop_not_on_strike_indicator'] = ([int(x < 0) for x in propworkers_list])
new_df['Wage_Increase_Indicator'] = ([int(x > 0) for x in minwages_list])
new_df.head()
# Should I clean FMCS df?
# Yes
# Out:
#   State  Year Strikers FMCS Interest valid strikers  Priv Union Members (%)  \
# 1    AK  1993        0             0              0                    10.3
# 2    AK  1994   2900.0             0         2900.0                    10.0
# 3    AK  1995        0             0              0                    11.4
# 4    AK  1996        0             0              0                    12.4
# 5    AK  1997        0             0              0                     9.6
#
#    Employed Workers Employed Workers not on strike prop not on strike  \
# 1          165000.0                       165000.0                1.0
# 2          163000.0                       160100.0           0.982209
# 3          151000.0                       151000.0                1.0
# 4          165000.0                       165000.0                1.0
# 5          169000.0                       169000.0                1.0
#
#    prop_rep  Min Wage  us_inf  state_inf  state_inf_t  state_inf_nt  \
# 1       NaN      4.75     3.3   9.708451     0.526923     16.330164
# 2  0.569233      4.75     2.8   6.019952     0.004207     10.459492
# 3  0.569233      4.75     3.0   7.812813     6.326159      9.473906
# 4  0.594069      4.75     2.7  12.149973     8.822973     14.476239
# 5  0.594069      5.25     2.4   8.288585     2.779384     11.776124
#
#    strikers_diff  union_mem_diff  change_prop_not_on_strike  \
# 1            NaN             NaN                        NaN
# 2    2899.000000       -0.029126                  -0.017791
# 3      -0.999655        0.140000                   0.018114
# 4       0.000000        0.087719                   0.000000
# 5       0.000000       -0.225806                   0.000000
#
#    change_prop_not_on_strike_indicator  Wage_Increase_Indicator
# 1                                    0                        0
# 2                                    1                        0
# 3                                    0                        0
# 4                                    0                        0
# 5                                    0                        1

# %%
testing_df = new_df.copy()
testing_df = testing_df[~testing_df['State'].isin(['AK','HI','VI'])]
testing_df
# Out:
#      State  Year Strikers FMCS Interest valid strikers  \
# 29      AL  1993   1200.0          6700        -5500.0
# 30      AL  1994   3200.0          2000         1200.0
# 31      AL  1995        0             0              0
# 32      AL  1996   1100.0          1100            0.0
# 33      AL  1997   1100.0          1000          100.0
# ...    ...   ...      ...           ...            ...
# 1452    WY  2016        0             0              0
# 1453    WY  2017        0             0              0
# 1454    WY  2018        0             0              0
# 1455    WY  2019        0             0              0
# 1456    WY  2020        0             0              0
#
#       Priv Union Members (%)  Employed Workers Employed Workers not on strike  \
# 29                      12.0         1381000.0                      1386500.0
# 30                       9.8         1399000.0                      1397800.0
# 31                      10.2         1436000.0                      1436000.0
# 32                       8.3         1470000.0                      1470000.0
# 33                       7.3         1524000.0                      1523900.0
# ...                      ...               ...                            ...
# 1452                     4.7          183000.0                       183000.0
# 1453                     4.4          182000.0                       182000.0
# 1454                     4.5          179000.0                       179000.0
# 1455                     5.1          181000.0                       181000.0
# 1456                     5.1          174000.0                       174000.0
#
#      prop not on strike  prop_rep  Min Wage  us_inf  state_inf  state_inf_t  \
# 29             1.003983       NaN      0.00     3.3  10.185112     5.596229
# 30             0.999142  0.500832      0.00     2.8   8.066068     4.430973
# 31                  1.0  0.500832      0.00     3.0   9.118135     2.915190
# 32                  1.0  0.534838      0.00     2.7  13.689258     8.739596
# 33             0.999934  0.534838      0.00     2.4   6.505301     3.322887
# ...                 ...       ...       ...     ...        ...          ...
# 1452                1.0  0.603490      5.15     2.2        NaN          NaN
# 1453                1.0  0.603490      5.15     1.8        NaN          NaN
# 1454                1.0  0.635857      5.15     2.1        NaN          NaN
# 1455                1.0  0.635857      5.15     2.2        NaN          NaN
# 1456                1.0  0.666894      5.15     1.7        NaN          NaN
#
#       state_inf_nt  strikers_diff  union_mem_diff  change_prop_not_on_strike  \
# 29       13.388873            NaN             NaN                        NaN
# 30       10.584267      -1.218182       -0.183333                  -0.004821
# 31       13.601187      -0.999167        0.040816                   0.000858
# 32       17.238443       0.000000       -0.186275                   0.000000
# 33        8.276711      99.000000       -0.120482                  -0.000066
# ...            ...            ...             ...                        ...
# 1452           NaN       0.000000       -0.078431                   0.000000
# 1453           NaN       0.000000       -0.063830                   0.000000
# 1454           NaN       0.000000        0.022727                   0.000000
# 1455           NaN       0.000000        0.133333                   0.000000
# 1456           NaN       0.000000        0.000000                   0.000000
#
#       change_prop_not_on_strike_indicator  Wage_Increase_Indicator
# 29                                      0                        0
# 30                                      1                        0
# 31                                      0                        0
# 32                                      0                        0
# 33                                      1                        0
# ...                                   ...                      ...
# 1452                                    0                        0
# 1453                                    0                        0
# 1454                                    0                        0
# 1455                                    0                        0
# 1456                                    0                        0
#
# [1372 rows x 20 columns]

# %%
sub_df_year = testing_df[testing_df['Year'] == 1994]
distances_df.loc[distances_df['state'] == state, :]['Closest State #' + str(2)].iloc[0]
sub_df_year[sub_df_year['State']=='ND']#['strikers_diff']
# Out:
#     State  Year Strikers FMCS Interest valid strikers  Priv Union Members (%)  \
# 786    ND  1994        0             0              0                     5.0
#
#      Employed Workers Employed Workers not on strike prop not on strike  \
# 786          196000.0                       196000.0                1.0
#
#      prop_rep  Min Wage  us_inf  state_inf  state_inf_t  state_inf_nt  \
# 786  0.450267      4.25     2.8        NaN          NaN           NaN
#
#      strikers_diff  union_mem_diff  change_prop_not_on_strike  \
# 786            0.0        0.162791                        0.0
#
#      change_prop_not_on_strike_indicator  Wage_Increase_Indicator
# 786                                    0                        0

# %%
all_states = testing_df['State'].unique().tolist()
testing_df['instrument_calc'] = np.nan
for year in np.arange(1994,2021):
    sub_df_year = testing_df[testing_df['Year'] == year]
    for state in all_states:
        sub_df_state = distances_df.loc[distances_df['state'] == state, :]
        instrument_calc = 0
        for i in range(5):
            closest_state_i = sub_df_state['Closest State #' + str(i + 1)].iloc[0]
            dist_to_closest_state_i = sub_df_state['Distance to Closest State #' + str(i + 1)].iloc[0]
            try:
                instrument_calc += dist_to_closest_state_i*sub_df_year[sub_df_year['State']==closest_state_i]['strikers_diff'].iloc[0]
            except:
                print(state, year)
        testing_df.loc[(testing_df['State'] == state) & (testing_df['Year'] == year),'instrument_calc'] = instrument_calc
testing_df = testing_df[testing_df['Year'] > 1993]
testing_df
# Out:
#      State  Year Strikers FMCS Interest valid strikers  \
# 30      AL  1994   3200.0          2000         1200.0
# 31      AL  1995        0             0              0
# 32      AL  1996   1100.0          1100            0.0
# 33      AL  1997   1100.0          1000          100.0
# 34      AL  1998        0             0              0
# ...    ...   ...      ...           ...            ...
# 1452    WY  2016        0             0              0
# 1453    WY  2017        0             0              0
# 1454    WY  2018        0             0              0
# 1455    WY  2019        0             0              0
# 1456    WY  2020        0             0              0
#
#       Priv Union Members (%)  Employed Workers Employed Workers not on strike  \
# 30                       9.8         1399000.0                      1397800.0
# 31                      10.2         1436000.0                      1436000.0
# 32                       8.3         1470000.0                      1470000.0
# 33                       7.3         1524000.0                      1523900.0
# 34                       6.2         1543000.0                      1543000.0
# ...                      ...               ...                            ...
# 1452                     4.7          183000.0                       183000.0
# 1453                     4.4          182000.0                       182000.0
# 1454                     4.5          179000.0                       179000.0
# 1455                     5.1          181000.0                       181000.0
# 1456                     5.1          174000.0                       174000.0
#
#      prop not on strike  prop_rep  ...  us_inf  state_inf  state_inf_t  \
# 30             0.999142  0.500832  ...     2.8   8.066068     4.430973
# 31                  1.0  0.500832  ...     3.0   9.118135     2.915190
# 32                  1.0  0.534838  ...     2.7  13.689258     8.739596
# 33             0.999934  0.534838  ...     2.4   6.505301     3.322887
# 34                  1.0  0.547759  ...     2.3   2.477222    -5.147837
# ...                 ...       ...  ...     ...        ...          ...
# 1452                1.0  0.603490  ...     2.2        NaN          NaN
# 1453                1.0  0.603490  ...     1.8        NaN          NaN
# 1454                1.0  0.635857  ...     2.1        NaN          NaN
# 1455                1.0  0.635857  ...     2.2        NaN          NaN
# 1456                1.0  0.666894  ...     1.7        NaN          NaN
#
#       state_inf_nt  strikers_diff  union_mem_diff  change_prop_not_on_strike  \
# 30       10.584267      -1.218182       -0.183333                  -0.004821
# 31       13.601187      -0.999167        0.040816                   0.000858
# 32       17.238443       0.000000       -0.186275                   0.000000
# 33        8.276711      99.000000       -0.120482                  -0.000066
# 34        7.581546      -0.990000       -0.150685                   0.000066
# ...            ...            ...             ...                        ...
# 1452           NaN       0.000000       -0.078431                   0.000000
# 1453           NaN       0.000000       -0.063830                   0.000000
# 1454           NaN       0.000000        0.022727                   0.000000
# 1455           NaN       0.000000        0.133333                   0.000000
# 1456           NaN       0.000000        0.000000                   0.000000
#
#       change_prop_not_on_strike_indicator  Wage_Increase_Indicator  \
# 30                                      1                        0
# 31                                      0                        0
# 32                                      0                        0
# 33                                      1                        0
# 34                                      0                        0
# ...                                   ...                      ...
# 1452                                    0                        0
# 1453                                    0                        0
# 1454                                    0                        0
# 1455                                    0                        0
# 1456                                    0                        0
#
#       instrument_calc
# 30       5.999579e+05
# 31       9.766157e+05
# 32       1.255837e+06
# 33      -1.653127e+02
# 34       1.750401e+06
# ...               ...
# 1452     0.000000e+00
# 1453     0.000000e+00
# 1454     1.859135e+07
# 1455    -2.768370e+02
# 1456    -2.950298e+02
#
# [1323 rows x 21 columns]

# %%
testing_df = testing_df[testing_df['State'].isin(min_wage_df[min_wage_df['Effective.Minimum.Wage'] > min_wage_df['Federal.Minimum.Wage']]['State'].unique().tolist())]
testing_df
# Out:
#      State  Year Strikers FMCS Interest valid strikers  \
# 58      AR  1994        0             0              0
# 59      AR  1995        0             0              0
# 60      AR  1996        0             0              0
# 61      AR  1997        0             0              0
# 62      AR  1998   1200.0          1200            0.0
# ...    ...   ...      ...           ...            ...
# 1424    SD  2016        0             0              0
# 1425    SD  2017        0             0              0
# 1426    SD  2018        0             0              0
# 1427    SD  2019        0             0              0
# 1428    SD  2020        0             0              0
#
#       Priv Union Members (%)  Employed Workers Employed Workers not on strike  \
# 58                       6.6          815000.0                       815000.0
# 59                       6.5          837000.0                       837000.0
# 60                       5.7          882000.0                       882000.0
# 61                       4.5          836000.0                       836000.0
# 62                       4.5          827000.0                       827000.0
# ...                      ...               ...                            ...
# 1424                     2.5          316000.0                       316000.0
# 1425                     2.5          315000.0                       315000.0
# 1426                     3.0          327000.0                       327000.0
# 1427                     2.6          333000.0                       333000.0
# 1428                     2.7          327000.0                       327000.0
#
#      prop not on strike  prop_rep  ...  us_inf  state_inf  state_inf_t  \
# 58                  1.0  0.525928  ...     2.8   9.261872     8.117365
# 59                  1.0  0.525928  ...     3.0   8.460396     4.543085
# 60                  1.0  0.528233  ...     2.7  11.403650     5.368576
# 61                  1.0  0.528233  ...     2.4   9.892886    -2.294520
# 62                  1.0  0.608904  ...     2.3  -0.291438    -6.662638
# ...                 ...       ...  ...     ...        ...          ...
# 1424                1.0  0.641028  ...     2.2        NaN          NaN
# 1425                1.0  0.641028  ...     1.8        NaN          NaN
# 1426                1.0  0.603468  ...     2.1        NaN          NaN
# 1427                1.0  0.603468  ...     2.2        NaN          NaN
# 1428                1.0  0.809550  ...     1.7        NaN          NaN
#
#       state_inf_nt  strikers_diff  union_mem_diff  change_prop_not_on_strike  \
# 58        9.712796            0.0       -0.120000                        0.0
# 59       11.004751            0.0       -0.015152                        0.0
# 60       15.706264            0.0       -0.123077                        0.0
# 61       18.751516            0.0       -0.210526                        0.0
# 62        5.208307            0.0        0.000000                        0.0
# ...            ...            ...             ...                        ...
# 1424           NaN            0.0       -0.038462                        0.0
# 1425           NaN            0.0        0.000000                        0.0
# 1426           NaN            0.0        0.200000                        0.0
# 1427           NaN            0.0       -0.133333                        0.0
# 1428           NaN            0.0        0.038462                        0.0
#
#       change_prop_not_on_strike_indicator  Wage_Increase_Indicator  \
# 58                                      0                        1
# 59                                      0                        0
# 60                                      0                        0
# 61                                      0                        0
# 62                                      0                        1
# ...                                   ...                      ...
# 1424                                    0                        1
# 1425                                    0                        1
# 1426                                    0                        1
# 1427                                    0                        1
# 1428                                    0                        0
#
#       instrument_calc
# 58       1.811185e+06
# 59       7.942910e+05
# 60       1.656710e+06
# 61       4.130359e+06
# 62       1.284137e+06
# ...               ...
# 1424     8.751774e+05
# 1425    -3.146988e+02
# 1426     0.000000e+00
# 1427     0.000000e+00
# 1428     1.133008e+06
#
# [891 rows x 21 columns]

# %%
testing_df['prop_rep'] = testing_df['prop_rep']*100

# %%
index_2 = testing_df[testing_df['Wage_Increase_Indicator']>0].groupby('State').size().index
index_2

# 45 states have atleast 1 min wage increase
# 16 of them don't have info on state inflation 
# Run 2 regressions

# Acc run 3, to also account for DC not having poli_lean
# Out:
# Index(['AR', 'AZ', 'CA', 'CO', 'CT', 'DC', 'DE', 'FL', 'IA', 'IL', 'MA', 'MD',
#        'ME', 'MI', 'MN', 'MO', 'MT', 'NC', 'NE', 'NH', 'NJ', 'NM', 'NV', 'NY',
#        'OH', 'OR', 'PA', 'RI', 'SD', 'VT', 'WA', 'WI', 'WV'],
#       dtype='object', name='State')

# %%
testing_df[['State','Year','strikers_diff','Priv Union Members (%)','prop_rep','Wage_Increase_Indicator','change_prop_not_on_strike','change_prop_not_on_strike_indicator','instrument_calc']]
# Change in proportion of private sector workers not on strike is very small
# Weak instrument, it is what it is
# Instead, take whether or not there is a change as your instrument
# Out:
#      State  Year  strikers_diff  Priv Union Members (%)   prop_rep  \
# 58      AR  1994            0.0                     6.6  52.592763
# 59      AR  1995            0.0                     6.5  52.592763
# 60      AR  1996            0.0                     5.7  52.823293
# 61      AR  1997            0.0                     4.5  52.823293
# 62      AR  1998            0.0                     4.5  60.890447
# ...    ...   ...            ...                     ...        ...
# 1424    SD  2016            0.0                     2.5  64.102786
# 1425    SD  2017            0.0                     2.5  64.102786
# 1426    SD  2018            0.0                     3.0  60.346796
# 1427    SD  2019            0.0                     2.6  60.346796
# 1428    SD  2020            0.0                     2.7  80.955015
#
#       Wage_Increase_Indicator  change_prop_not_on_strike  \
# 58                          1                        0.0
# 59                          0                        0.0
# 60                          0                        0.0
# 61                          0                        0.0
# 62                          1                        0.0
# ...                       ...                        ...
# 1424                        1                        0.0
# 1425                        1                        0.0
# 1426                        1                        0.0
# 1427                        1                        0.0
# 1428                        0                        0.0
#
#       change_prop_not_on_strike_indicator  instrument_calc
# 58                                      0     1.811185e+06
# 59                                      0     7.942910e+05
# 60                                      0     1.656710e+06
# 61                                      0     4.130359e+06
# 62                                      0     1.284137e+06
# ...                                   ...              ...
# 1424                                    0     8.751774e+05
# 1425                                    0    -3.146988e+02
# 1426                                    0     0.000000e+00
# 1427                                    0     0.000000e+00
# 1428                                    0     1.133008e+06
#
# [891 rows x 9 columns]

# %%
df_1 = testing_df[['State','Year','strikers_diff','Priv Union Members (%)','state_inf','state_inf_t','state_inf_nt','prop_rep','Wage_Increase_Indicator','change_prop_not_on_strike','change_prop_not_on_strike_indicator','instrument_calc','us_inf']]
df_1 = df_1[df_1['State'].isin(index_2.tolist())]
df_1 = df_1[~df_1['state_inf'].isna()]
df_1 = df_1[~df_1['prop_rep'].isna()]
df_1 = pd.concat([df_1, pd.get_dummies(df_1['Year']).drop(columns=[1994])],axis=1)
df_1.columns = [x for x in df_1.columns.tolist() if type(x)!=int] + ['yr'+str(x) for x in df_1.columns.tolist() if type(x)==int]
df_1
#All states with inflation data, 1994-2017

df_1[['Priv Union Members (%)','state_inf','prop_rep','change_prop_not_on_strike_indicator',
      'Wage_Increase_Indicator','instrument_calc']].to_csv("all_states_w_inflation.csv")

# %%
df_1.describe()[['Priv Union Members (%)','state_inf','prop_rep','change_prop_not_on_strike_indicator','Wage_Increase_Indicator','instrument_calc']]
# Out:
#        Priv Union Members (%)   state_inf    prop_rep  \
# count              456.000000  456.000000  456.000000
# mean                 9.114254    8.985010   45.082164
# std                  3.910835    4.880890   10.001281
# min                  1.200000   -9.742371    8.848690
# 25%                  6.900000    6.408922   41.367813
# 50%                  9.100000    9.098480   46.318302
# 75%                 11.700000   11.996805   51.105978
# max                 18.400000   27.903131   71.161461
#
#        change_prop_not_on_strike_indicator  Wage_Increase_Indicator  \
# count                           456.000000               456.000000
# mean                              0.280702                 0.375000
# std                               0.449836                 0.484655
# min                               0.000000                 0.000000
# 25%                               0.000000                 0.000000
# 50%                               0.000000                 0.000000
# 75%                               1.000000                 1.000000
# max                               1.000000                 1.000000
#
#        instrument_calc
# count     4.560000e+02
# mean      2.801256e+06
# std       1.303664e+07
# min      -1.693096e+03
# 25%      -1.418277e+02
# 50%       3.233087e+02
# 75%       6.206984e+05
# max       1.607391e+08

# %%
df_1.groupby('State').mean().corr()
# Out:
#                                      strikers_diff  Priv Union Members (%)  \
# strikers_diff                             1.000000               -0.154183
# Priv Union Members (%)                   -0.154183                1.000000
# state_inf                                 0.283765                0.270695
# state_inf_t                               0.690667               -0.035479
# state_inf_nt                              0.040011                0.178884
# prop_rep                                 -0.128816               -0.318064
# Wage_Increase_Indicator                   0.260445                0.139784
# change_prop_not_on_strike                 0.687359               -0.281236
# change_prop_not_on_strike_indicator      -0.284422                0.721259
# instrument_calc                           0.127987                0.234832
# us_inf                                         NaN                     NaN
# yr1995                                         NaN                     NaN
# yr1996                                         NaN                     NaN
# yr1997                                         NaN                     NaN
# yr1998                                         NaN                     NaN
# yr1999                                         NaN                     NaN
# yr2000                                         NaN                     NaN
# yr2001                                         NaN                     NaN
# yr2002                                         NaN                     NaN
# yr2003                                         NaN                     NaN
# yr2004                                         NaN                     NaN
# yr2005                                         NaN                     NaN
# yr2006                                         NaN                     NaN
# yr2007                                         NaN                     NaN
# yr2008                                         NaN                     NaN
# yr2009                                         NaN                     NaN
# yr2010                                         NaN                     NaN
# yr2011                                         NaN                     NaN
# yr2012                                         NaN                     NaN
# yr2013                                         NaN                     NaN
# yr2014                                         NaN                     NaN
# yr2015                                         NaN                     NaN
# yr2016                                         NaN                     NaN
# yr2017                                         NaN                     NaN
#
#                                      state_inf  state_inf_t  state_inf_nt  \
# strikers_diff                         0.283765     0.690667      0.040011
# Priv Union Members (%)                0.270695    -0.035479      0.178884
# state_inf                             1.000000     0.688964      0.887592
# state_inf_t                           0.688964     1.000000      0.411220
# state_inf_nt                          0.887592     0.411220      1.000000
# prop_rep                             -0.032799    -0.161151      0.097719
# Wage_Increase_Indicator               0.382842     0.539590      0.354825
# change_prop_not_on_strike             0.104800     0.522675     -0.074772
# change_prop_not_on_strike_indicator   0.174437    -0.097559      0.100773
# instrument_calc                       0.484394     0.487353      0.351747
# us_inf                                     NaN          NaN           NaN
# yr1995                                     NaN          NaN           NaN
# yr1996                                     NaN          NaN           NaN
# yr1997                                     NaN          NaN           NaN
# yr1998                                     NaN          NaN           NaN
# yr1999                                     NaN          NaN           NaN
# yr2000                                     NaN          NaN           NaN
# yr2001                                     NaN          NaN           NaN
# yr2002                                     NaN          NaN           NaN
# yr2003                                     NaN          NaN           NaN
# yr2004                                     NaN          NaN           NaN
# yr2005                                     NaN          NaN           NaN
# yr2006                                     NaN          NaN           NaN
# yr2007                                     NaN          NaN           NaN
# yr2008                                     NaN          NaN           NaN
# yr2009                                     NaN          NaN           NaN
# yr2010                                     NaN          NaN           NaN
# yr2011                                     NaN          NaN           NaN
# yr2012                                     NaN          NaN           NaN
# yr2013                                     NaN          NaN           NaN
# yr2014                                     NaN          NaN           NaN
# yr2015                                     NaN          NaN           NaN
# yr2016                                     NaN          NaN           NaN
# yr2017                                     NaN          NaN           NaN
#
#                                      prop_rep  Wage_Increase_Indicator  \
# strikers_diff                       -0.128816                 0.260445
# Priv Union Members (%)              -0.318064                 0.139784
# state_inf                           -0.032799                 0.382842
# state_inf_t                         -0.161151                 0.539590
# state_inf_nt                         0.097719                 0.354825
# prop_rep                             1.000000                -0.220108
# Wage_Increase_Indicator             -0.220108                 1.000000
# change_prop_not_on_strike            0.093953                 0.101174
# change_prop_not_on_strike_indicator -0.169498                 0.099478
# instrument_calc                     -0.137249                 0.591030
# us_inf                                    NaN                      NaN
# yr1995                                    NaN                      NaN
# yr1996                                    NaN                      NaN
# yr1997                                    NaN                      NaN
# yr1998                                    NaN                      NaN
# yr1999                                    NaN                      NaN
# yr2000                                    NaN                      NaN
# yr2001                                    NaN                      NaN
# yr2002                                    NaN                      NaN
# yr2003                                    NaN                      NaN
# yr2004                                    NaN                      NaN
# yr2005                                    NaN                      NaN
# yr2006                                    NaN                      NaN
# yr2007                                    NaN                      NaN
# yr2008                                    NaN                      NaN
# yr2009                                    NaN                      NaN
# yr2010                                    NaN                      NaN
# yr2011                                    NaN                      NaN
# yr2012                                    NaN                      NaN
# yr2013                                    NaN                      NaN
# yr2014                                    NaN                      NaN
# yr2015                                    NaN                      NaN
# yr2016                                    NaN                      NaN
# yr2017                                    NaN                      NaN
#
#                                      change_prop_not_on_strike  \
# strikers_diff                                         0.687359
# Priv Union Members (%)                               -0.281236
# state_inf                                             0.104800
# state_inf_t                                           0.522675
# state_inf_nt                                         -0.074772
# prop_rep                                              0.093953
# Wage_Increase_Indicator                               0.101174
# change_prop_not_on_strike                             1.000000
# change_prop_not_on_strike_indicator                  -0.347962
# instrument_calc                                       0.185929
# us_inf                                                     NaN
# yr1995                                                     NaN
# yr1996                                                     NaN
# yr1997                                                     NaN
# yr1998                                                     NaN
# yr1999                                                     NaN
# yr2000                                                     NaN
# yr2001                                                     NaN
# yr2002                                                     NaN
# yr2003                                                     NaN
# yr2004                                                     NaN
# yr2005                                                     NaN
# yr2006                                                     NaN
# yr2007                                                     NaN
# yr2008                                                     NaN
# yr2009                                                     NaN
# yr2010                                                     NaN
# yr2011                                                     NaN
# yr2012                                                     NaN
# yr2013                                                     NaN
# yr2014                                                     NaN
# yr2015                                                     NaN
# yr2016                                                     NaN
# yr2017                                                     NaN
#
#                                      change_prop_not_on_strike_indicator  \
# strikers_diff                                                  -0.284422
# Priv Union Members (%)                                          0.721259
# state_inf                                                       0.174437
# state_inf_t                                                    -0.097559
# state_inf_nt                                                    0.100773
# prop_rep                                                       -0.169498
# Wage_Increase_Indicator                                         0.099478
# change_prop_not_on_strike                                      -0.347962
# change_prop_not_on_strike_indicator                             1.000000
# instrument_calc                                                 0.387642
# us_inf                                                               NaN
# yr1995                                                               NaN
# yr1996                                                               NaN
# yr1997                                                               NaN
# yr1998                                                               NaN
# yr1999                                                               NaN
# yr2000                                                               NaN
# yr2001                                                               NaN
# yr2002                                                               NaN
# yr2003                                                               NaN
# yr2004                                                               NaN
# yr2005                                                               NaN
# yr2006                                                               NaN
# yr2007                                                               NaN
# yr2008                                                               NaN
# yr2009                                                               NaN
# yr2010                                                               NaN
# yr2011                                                               NaN
# yr2012                                                               NaN
# yr2013                                                               NaN
# yr2014                                                               NaN
# yr2015                                                               NaN
# yr2016                                                               NaN
# yr2017                                                               NaN
#
#                                      instrument_calc  ...  yr2008  yr2009  \
# strikers_diff                               0.127987  ...     NaN     NaN
# Priv Union Members (%)                      0.234832  ...     NaN     NaN
# state_inf                                   0.484394  ...     NaN     NaN
# state_inf_t                                 0.487353  ...     NaN     NaN
# state_inf_nt                                0.351747  ...     NaN     NaN
# prop_rep                                   -0.137249  ...     NaN     NaN
# Wage_Increase_Indicator                     0.591030  ...     NaN     NaN
# change_prop_not_on_strike                   0.185929  ...     NaN     NaN
# change_prop_not_on_strike_indicator         0.387642  ...     NaN     NaN
# instrument_calc                             1.000000  ...     NaN     NaN
# us_inf                                           NaN  ...     NaN     NaN
# yr1995                                           NaN  ...     NaN     NaN
# yr1996                                           NaN  ...     NaN     NaN
# yr1997                                           NaN  ...     NaN     NaN
# yr1998                                           NaN  ...     NaN     NaN
# yr1999                                           NaN  ...     NaN     NaN
# yr2000                                           NaN  ...     NaN     NaN
# yr2001                                           NaN  ...     NaN     NaN
# yr2002                                           NaN  ...     NaN     NaN
# yr2003                                           NaN  ...     NaN     NaN
# yr2004                                           NaN  ...     NaN     NaN
# yr2005                                           NaN  ...     NaN     NaN
# yr2006                                           NaN  ...     NaN     NaN
# yr2007                                           NaN  ...     NaN     NaN
# yr2008                                           NaN  ...     NaN     NaN
# yr2009                                           NaN  ...     NaN     NaN
# yr2010                                           NaN  ...     NaN     NaN
# yr2011                                           NaN  ...     NaN     NaN
# yr2012                                           NaN  ...     NaN     NaN
# yr2013                                           NaN  ...     NaN     NaN
# yr2014                                           NaN  ...     NaN     NaN
# yr2015                                           NaN  ...     NaN     NaN
# yr2016                                           NaN  ...     NaN     NaN
# yr2017                                           NaN  ...     NaN     NaN
#
#                                      yr2010  yr2011  yr2012  yr2013  yr2014  \
# strikers_diff                           NaN     NaN     NaN     NaN     NaN
# Priv Union Members (%)                  NaN     NaN     NaN     NaN     NaN
# state_inf                               NaN     NaN     NaN     NaN     NaN
# state_inf_t                             NaN     NaN     NaN     NaN     NaN
# state_inf_nt                            NaN     NaN     NaN     NaN     NaN
# prop_rep                                NaN     NaN     NaN     NaN     NaN
# Wage_Increase_Indicator                 NaN     NaN     NaN     NaN     NaN
# change_prop_not_on_strike               NaN     NaN     NaN     NaN     NaN
# change_prop_not_on_strike_indicator     NaN     NaN     NaN     NaN     NaN
# instrument_calc                         NaN     NaN     NaN     NaN     NaN
# us_inf                                  NaN     NaN     NaN     NaN     NaN
# yr1995                                  NaN     NaN     NaN     NaN     NaN
# yr1996                                  NaN     NaN     NaN     NaN     NaN
# yr1997                                  NaN     NaN     NaN     NaN     NaN
# yr1998                                  NaN     NaN     NaN     NaN     NaN
# yr1999                                  NaN     NaN     NaN     NaN     NaN
# yr2000                                  NaN     NaN     NaN     NaN     NaN
# yr2001                                  NaN     NaN     NaN     NaN     NaN
# yr2002                                  NaN     NaN     NaN     NaN     NaN
# yr2003                                  NaN     NaN     NaN     NaN     NaN
# yr2004                                  NaN     NaN     NaN     NaN     NaN
# yr2005                                  NaN     NaN     NaN     NaN     NaN
# yr2006                                  NaN     NaN     NaN     NaN     NaN
# yr2007                                  NaN     NaN     NaN     NaN     NaN
# yr2008                                  NaN     NaN     NaN     NaN     NaN
# yr2009                                  NaN     NaN     NaN     NaN     NaN
# yr2010                                  NaN     NaN     NaN     NaN     NaN
# yr2011                                  NaN     NaN     NaN     NaN     NaN
# yr2012                                  NaN     NaN     NaN     NaN     NaN
# yr2013                                  NaN     NaN     NaN     NaN     NaN
# yr2014                                  NaN     NaN     NaN     NaN     NaN
# yr2015                                  NaN     NaN     NaN     NaN     NaN
# yr2016                                  NaN     NaN     NaN     NaN     NaN
# yr2017                                  NaN     NaN     NaN     NaN     NaN
#
#                                      yr2015  yr2016  yr2017
# strikers_diff                           NaN     NaN     NaN
# Priv Union Members (%)                  NaN     NaN     NaN
# state_inf                               NaN     NaN     NaN
# state_inf_t                             NaN     NaN     NaN
# state_inf_nt                            NaN     NaN     NaN
# prop_rep                                NaN     NaN     NaN
# Wage_Increase_Indicator                 NaN     NaN     NaN
# change_prop_not_on_strike               NaN     NaN     NaN
# change_prop_not_on_strike_indicator     NaN     NaN     NaN
# instrument_calc                         NaN     NaN     NaN
# us_inf                                  NaN     NaN     NaN
# yr1995                                  NaN     NaN     NaN
# yr1996                                  NaN     NaN     NaN
# yr1997                                  NaN     NaN     NaN
# yr1998                                  NaN     NaN     NaN
# yr1999                                  NaN     NaN     NaN
# yr2000                                  NaN     NaN     NaN
# yr2001                                  NaN     NaN     NaN
# yr2002                                  NaN     NaN     NaN
# yr2003                                  NaN     NaN     NaN
# yr2004                                  NaN     NaN     NaN
# yr2005                                  NaN     NaN     NaN
# yr2006                                  NaN     NaN     NaN
# yr2007                                  NaN     NaN     NaN
# yr2008                                  NaN     NaN     NaN
# yr2009                                  NaN     NaN     NaN
# yr2010                                  NaN     NaN     NaN
# yr2011                                  NaN     NaN     NaN
# yr2012                                  NaN     NaN     NaN
# yr2013                                  NaN     NaN     NaN
# yr2014                                  NaN     NaN     NaN
# yr2015                                  NaN     NaN     NaN
# yr2016                                  NaN     NaN     NaN
# yr2017                                  NaN     NaN     NaN
#
# [34 rows x 34 columns]

# %%
plt.figure(figsize=(25,20));
sns.lmplot(data = df_1.groupby('State').mean(),
           x = 'instrument_calc', y='change_prop_not_on_strike_indicator', fit_reg=True,ci=50);
plt.title('The Average Instrumental Variable vs Average Endogenous Variable by State');
plt.xlabel('Avg Spillover Effects',labelpad=20);
plt.ylabel('Average Indicator for Increase in Proportional Strike Activity');

# %%
len(df_1['State'].unique())
# Out:
# 19

# %%
df_2 = testing_df[['State','Year','strikers_diff','Priv Union Members (%)','prop_rep','Wage_Increase_Indicator','change_prop_not_on_strike','change_prop_not_on_strike_indicator','instrument_calc','us_inf']]
df_2 = df_2[df_2['State'].isin(index_2.tolist())]
df_2 = df_2[~df_2['prop_rep'].isna()]
df_2 = pd.concat([df_2, pd.get_dummies(df_2['Year']).drop(columns=[1994])],axis=1)
df_2.columns = [x for x in df_2.columns.tolist() if type(x)!=int] + ['yr'+str(x) for x in df_2.columns.tolist() if type(x)==int]
df_2
#All states without inflation data, 1994-2020

df_2[['Priv Union Members (%)','us_inf','prop_rep','change_prop_not_on_strike_indicator','Wage_Increase_Indicator',
      'instrument_calc']].to_csv("all_states_no_inflation.csv")

# %%
df_2.describe()[['Priv Union Members (%)','us_inf','prop_rep','change_prop_not_on_strike_indicator','Wage_Increase_Indicator','instrument_calc']]
# Out:
#        Priv Union Members (%)      us_inf    prop_rep  \
# count              864.000000  864.000000  864.000000
# mean                 7.926736    2.111111   46.161226
# std                  3.726034    0.438545   12.274142
# min                  1.200000    1.000000    0.000000
# 25%                  4.900000    1.800000   40.115674
# 50%                  7.800000    2.200000   46.594214
# 75%                 10.300000    2.400000   53.909956
# max                 18.400000    3.000000   81.649972
#
#        change_prop_not_on_strike_indicator  Wage_Increase_Indicator  \
# count                           864.000000               864.000000
# mean                              0.221065                 0.364583
# std                               0.415204                 0.481592
# min                               0.000000                 0.000000
# 25%                               0.000000                 0.000000
# 50%                               0.000000                 0.000000
# 75%                               0.000000                 1.000000
# max                               1.000000                 1.000000
#
#        instrument_calc
# count     8.640000e+02
# mean      3.219565e+06
# std       1.471033e+07
# min      -9.663032e+03
# 25%      -1.833559e+02
# 50%       3.232298e+02
# 75%       7.317261e+05
# max       2.150895e+08

# %%
df_3 = testing_df[['State','Year','strikers_diff','Priv Union Members (%)','Wage_Increase_Indicator','change_prop_not_on_strike','change_prop_not_on_strike_indicator','instrument_calc','us_inf']]
df_3 = df_3[df_3['State'].isin(index_2.tolist())]
df_3 = pd.concat([df_3, pd.get_dummies(df_3['Year']).drop(columns=[1994])],axis=1)
df_3.columns = [x for x in df_3.columns.tolist() if type(x)!=int] + ['yr'+str(x) for x in df_3.columns.tolist() if type(x)==int]
df_3
#All states without political lean data (including DC), 1994-2020

df_3[['Priv Union Members (%)','us_inf','change_prop_not_on_strike_indicator',
      'Wage_Increase_Indicator','instrument_calc']].to_csv("all_states_no_poli.csv")

# %%
df_3.describe()[['Priv Union Members (%)','us_inf','change_prop_not_on_strike_indicator','Wage_Increase_Indicator','instrument_calc']]
# Out:
#        Priv Union Members (%)      us_inf  \
# count              891.000000  891.000000
# mean                 7.914366    2.111111
# std                  3.686385    0.438537
# min                  1.200000    1.000000
# 25%                  4.950000    1.800000
# 50%                  7.800000    2.200000
# 75%                 10.200000    2.400000
# max                 18.400000    3.000000
#
#        change_prop_not_on_strike_indicator  Wage_Increase_Indicator  \
# count                           891.000000               891.000000
# mean                              0.218855                 0.368126
# std                               0.413702                 0.482567
# min                               0.000000                 0.000000
# 25%                               0.000000                 0.000000
# 50%                               0.000000                 0.000000
# 75%                               0.000000                 1.000000
# max                               1.000000                 1.000000
#
#        instrument_calc
# count     8.910000e+02
# mean      3.164306e+06
# std       1.451806e+07
# min      -9.663032e+03
# 25%      -1.769628e+02
# 50%       3.307819e+02
# 75%       7.209879e+05
# max       2.150895e+08
