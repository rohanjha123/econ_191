# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import plotly as pl
import seaborn as sns
# %matplotlib inline

# %%
min_wage_df = pd.read_csv("min_wage.csv",encoding='cp1252')
min_wage_df = min_wage_df[min_wage_df['Year'] >= 1993]
min_wage_df
# Out:
#       Year          State  State.Minimum.Wage  \
# 1350  1993        Alabama                0.00
# 1351  1993         Alaska                4.75
# 1352  1993        Arizona                0.00
# 1353  1993       Arkansas                3.65
# 1354  1993     California                4.25
# ...    ...            ...                 ...
# 2857  2020       Virginia                7.25
# 2858  2020     Washington               13.50
# 2859  2020  West Virginia                8.75
# 2860  2020      Wisconsin                7.25
# 2861  2020        Wyoming                5.15
#
#       State.Minimum.Wage.2020.Dollars  Federal.Minimum.Wage  \
# 1350                             0.00                  4.25
# 1351                             8.50                  4.25
# 1352                             0.00                  4.25
# 1353                             6.53                  4.25
# 1354                             7.61                  4.25
# ...

# %%
us_state_to_abbrev = {"State" : {
    "Alabama": "AL",
    "Alaska": "AK",
    "Arizona": "AZ",
    "Arkansas": "AR",
    "California": "CA",
    "Colorado": "CO",
    "Connecticut": "CT",
    "Delaware": "DE",
    "Florida": "FL",
    "Georgia": "GA",
    "Hawaii": "HI",
    "Idaho": "ID",
    "Illinois": "IL",
    "Indiana": "IN",
    "Iowa": "IA",
    "Kansas": "KS",
    "Kentucky": "KY",
    "Louisiana": "LA",
    "Maine": "ME",
    "Maryland": "MD",
    "Massachusetts": "MA",
    "Michigan": "MI",
    "Minnesota": "MN",
    "Mississippi": "MS",
    "Missouri": "MO",
    "Montana": "MT",
    "Nebraska": "NE",
    "Nevada": "NV",
    "New Hampshire": "NH",
    "New Jersey": "NJ",
    "New Mexico": "NM",
    "New York": "NY",
    "North Carolina": "NC",
    "North Dakota": "ND",
    "Ohio": "OH",
    "Oklahoma": "OK",
    "Oregon": "OR",
    "Pennsylvania": "PA",
    "Rhode Island": "RI",
    "South Carolina": "SC",
    "South Dakota": "SD",
    "Tennessee": "TN",
    "Texas": "TX",
    "Utah": "UT",
    "Vermont": "VT",
    "Virginia": "VA",
    "Washington": "WA",
    "West Virginia": "WV",
    "Wisconsin": "WI",
    "Wyoming": "WY",
    "District of Columbia": "DC",
    "American Samoa": "AS",
    "Guam": "GU",
    "Northern Mariana Islands": "MP",
    "Puerto Rico": "PR",
    "United States Minor Outlying Islands": "UM",
    "U.S. Virgin Islands": "VI",
}}
min_wage_df = min_wage_df.replace(us_state_to_abbrev)
min_wage_df
# Out:
#       Year State  State.Minimum.Wage  State.Minimum.Wage.2020.Dollars  \
# 1350  1993    AL                0.00                             0.00
# 1351  1993    AK                4.75                             8.50
# 1352  1993    AZ                0.00                             0.00
# 1353  1993    AR                3.65                             6.53
# 1354  1993    CA                4.25                             7.61
# ...    ...   ...                 ...                              ...
# 2857  2020    VA                7.25                             7.25
# 2858  2020    WA               13.50                            13.50
# 2859  2020    WV                8.75                             8.75
# 2860  2020    WI                7.25                             7.25
# 2861  2020    WY                5.15                             5.15
#
#       Federal.Minimum.Wage  Federal.Minimum.Wage.2020.Dollars  \
# 1350                  4.25                               7.61
# ...

# %%
min_wage_df.sort_values(['State','Year'])
# Out:
#       Year State  State.Minimum.Wage  State.Minimum.Wage.2020.Dollars  \
# 1351  1993    AK                4.75                             8.50
# 1405  1994    AK                4.75                             8.29
# 1459  1995    AK                4.75                             8.06
# 1513  1996    AK                4.75                             7.83
# 1567  1997    AK                5.25                             8.46
# ...    ...   ...                 ...                              ...
# 2645  2016    WY                5.15                             5.55
# 2699  2017    WY                5.15                             5.43
# 2753  2018    WY                5.15                             5.30
# 2807  2019    WY                5.15                             5.21
# 2861  2020    WY                5.15                             5.15
#
#       Federal.Minimum.Wage  Federal.Minimum.Wage.2020.Dollars  \
# 1351                  4.25                               7.61
# ...
